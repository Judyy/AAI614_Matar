# %% [markdown]
# <a href="https://colab.research.google.com/github/Judyy/AAI614_Matar/blob/main/Notebook3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 3.1: Practice with Data Collections*
#
#
#
# Source: Scraping with Python http://shop.oreilly.com/product/0636920034391.do

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Other_ventures
# #Six_Degrees_of_Kevin_Bacon
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://be.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%B0%D0%BD
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://uz.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1256274242
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1256274242&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com
# #cite_note-1
# #cite_note-actor-2
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/X-Men:_First_Class
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# #cite_note-3
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# #cite_note-6
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# #cite_note-actor-2
# #cite_note-actor-2
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-10
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-11
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-12
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-13
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-14
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-15
# /wiki/Footloose_(1984_film)
# #cite_note-bio-13
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-16
# #cite_note-bacon-7
# #cite_note-17
# #cite_note-18
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# #cite_note-19
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-13
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-20
# /wiki/Tremors_(1990_film)
# #cite_note-21
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-13
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-13
# /wiki/The_New_York_Times
# #cite_note-nyt94-22
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-23
# /wiki/A_Few_Good_Men_(film)
# #cite_note-24
# /wiki/Michael_Greif
# #cite_note-bio-13
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-13
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-13
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-25
# /wiki/Sleepers_(film)
# #cite_note-26
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-13
# /wiki/Losing_Chase
# #cite_note-austin-27
# /wiki/Digging_to_China
# #cite_note-bio-13
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-13
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-28
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-29
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-30
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-31
# /wiki/My_Dog_Skip_(film)
# #cite_note-32
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-33
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-34
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_05_(21267276740).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-35
# #cite_note-36
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-37
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-38
# #cite_note-39
# /wiki/The_Following
# #cite_note-40
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-41
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-42
# /wiki/Tremors_5:_Bloodline
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-43
# /wiki/Instagram
# #cite_note-44
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# #cite_note-45
# /wiki/EE_(telecommunications)
# #cite_note-46
# #cite_note-47
# #cite_note-48
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-49
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-50
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-51
# /wiki/File:Kevin_Bacon_2_SDCC_2014.jpg
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-11
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Black_Anvil
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-52
# /wiki/Tracy_Pollan
# #cite_note-53
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-54
# #cite_note-55
# /wiki/The_Times
# /wiki/Atheism
# #cite_note-56
# /wiki/Antireligion
# #cite_note-57
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-58
# #cite_note-59
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-60
# #cite_note-61
# #cite_note-62
# #cite_note-63
# /wiki/Apollo_13_(film)
# #cite_note-64
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-65
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-66
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-67
# /wiki/Denver_Film_Festival
# #cite_note-68
# /wiki/Phoenix_Film_Festival
# #cite_note-69
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-70
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-71
# /wiki/Seattle_International_Film_Festival
# #cite_note-72
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_2-0
# #cite_ref-actor_2-1
# #cite_ref-actor_2-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-3
# https://www.hollywoodreporter.com/tv/tv-news/showtime-cancels-city-on-a-hill-3-seasons-1235250089/
# /wiki/The_Hollywood_Reporter
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-6
# https://www.marketingweek.com/ee-unveils-six-degrees-of-bacon-launch-ads/
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-walk_10-0
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-cosmo91_11-0
# #cite_ref-cosmo91_11-1
# #cite_ref-12
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_13-0
# #cite_ref-bio_13-1
# #cite_ref-bio_13-2
# #cite_ref-bio_13-3
# #cite_ref-bio_13-4
# #cite_ref-bio_13-5
# #cite_ref-bio_13-6
# #cite_ref-bio_13-7
# #cite_ref-bio_13-8
# #cite_ref-bio_13-9
# #cite_ref-bio_13-10
# https://web.archive.org/web/20160530033240/http://www.pbs.org/weta/finding-your-roots/profiles/kevin-bacon%c2%a0/
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_14-0
# https://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-15
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_16-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-17
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-18
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-19
# https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles
# #cite_ref-20
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-21
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_22-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-23
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-24
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-25
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-26
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_27-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-28
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-29
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-30
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-31
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# /wiki/Template:Cite_news
# /wiki/Category:CS1_maint:_unfit_URL
# #cite_ref-32
# https://archive.nytimes.com/www.nytimes.com/library/film/011200skip-film-review.html
# #cite_ref-33
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-34
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-35
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-36
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_37-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_38-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-39
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-40
# http://www.fox.com/the-following/
# #cite_ref-41
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-42
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-43
# http://baconbros.com/
# #cite_ref-44
# https://www.instagram.com/p/ClUvj92p4Qn/?hl=en
# #cite_ref-45
# https://www.marvel.com/articles/tv-shows/guardians-of-the-galaxy-holiday-special-soundtrack
# #cite_ref-46
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-47
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-48
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# /wiki/CNN
# #cite_ref-49
# http://www.sixdegrees.org/
# #cite_ref-50
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-51
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-52
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-53
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-54
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-55
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-56
# #cite_ref-57
# https://www.foxnews.com/story/the-bacon-brothers-go-on-the-record
# #cite_ref-financialpost_58-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-59
# #cite_ref-60
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-61
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-62
# http://www.drawtheline.org/sign-now/
# #cite_ref-63
# https://web.archive.org/web/20190214002809/http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-64
# https://web.archive.org/web/20190520150327/http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-65
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-66
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-67
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-68
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-69
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-70
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-71
# https://archive.today/20180123031007/http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-72
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb_(identifier)
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# /wiki/Special:EditPage/Template:Kevin_Bacon
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Special:EditPage/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Special:EditPage/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Special:EditPage/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Special:EditPage/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# https://isni.org/isni/0000000121291300
# https://viaf.org/viaf/39570812
# http://id.worldcat.org/fast/242183/
# https://id.oclc.org/worldcat/entity/E39PBJyWTmRrCjK87VWCKb9v73
# https://d-nb.info/gnd/124109659
# https://id.loc.gov/authorities/n88034930
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://nla.gov.au/anbd.aut-an36021861
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# http://data.bibliotheken.nl/id/thes/p147880998
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://lod.nl.go.kr/resource/KAC2020K8226
# https://dbn.bn.org.pl/descriptor-details/9810630778405606
# http://olduli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://cantic.bnc.cat/registre/981061093903206706
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://trove.nla.gov.au/people/1189569
# https://www.idref.fr/067287832
# https://snaccooperative.org/ark:/99166/w6w67gw2
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1256274242
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Male_actors_from_Manhattan
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:CS1_maint:_unfit_URL
# /wiki/Category:Use_American_English_from_April_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_April_2023
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# https://wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Black_Anvil
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Black_Anvil
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now().strftime('%s'))
def getLinks(articleUrl):
    html = urlopen(f'http://en.wikipedia.org{articleUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# Streaming output truncated to the last 5000 lines.
# /wiki/Daylife
# /wiki/Amarok_(software)
# /wiki/Xine
# /wiki/Audacious_(software)
# /wiki/Plex_(company)
# /wiki/S4C
# /wiki/Latvijas_Radio
# /wiki/Office_de_Radiodiffusion_T%C3%A9l%C3%A9vision_Fran%C3%A7aise
# /wiki/RTVE
# /wiki/Bulgarian_National_Television
# /wiki/TV_Globo
# /wiki/Da_Cor_do_Pecado
# /wiki/Carolina_Dieckmann
# /wiki/Adriana_Esteves
# /wiki/Avenida_Brasil_(TV_series)
# /wiki/Louco_Amor_(1983_TV_series)
# /wiki/O_S%C3%A9timo_Guardi%C3%A3o
# /wiki/Renascer_(2024_TV_series)
# /wiki/Andando_nas_Nuvens
# /wiki/Anjo_Mau_(1997_TV_series)
# /wiki/L%C3%ADlia_Cabral
# /wiki/Corpo_a_Corpo
# /wiki/O_Santo_Mesti%C3%A7o
# /wiki/Desejos_de_Mulher
# /wiki/Orgulho_e_Paix%C3%A3o
# /wiki/Salve-se_Quem_Puder
# /wiki/O_Amor_Est%C3%A1_no_Ar
# /wiki/Tato_Gabus_Mendes
# /wiki/C%C3%A1ssio_Gabus_Mendes
# /wiki/Voc%C3%AA_Decide
# /wiki/Susana_Werner
# /wiki/Rio_de_Janeiro
# /wiki/Tornado
# /wiki/Pacific_Northwest_windstorm
# /wiki/Bibcode_(identifier)
# /wiki/Kluwer_Academic_Publishers
# /wiki/Macmillan_Children%27s_Books
# /wiki/Rowohlt_Verlag
# /wiki/Daniel_Kehlmann
# /wiki/Ingeborg_Bachmann
# /wiki/Futurism
# /wiki/The_Eight_(painters)
# /wiki/Endre_Ady
# /wiki/J%C3%A1nos_Vajda_(poet)
# /wiki/J%C3%B3zsef_Ny%C3%ADr%C5%91
# /wiki/G%C3%A9za_Sz%C5%91cs
# /wiki/Hungarian_Writers%27_Union
# /wiki/P%C3%A9ter_Veres_(politician)
# /wiki/Hajd%C3%BA_County
# /wiki/Z%C3%B3lyom_County
# /wiki/Temes_County
# /wiki/Bars_County
# /wiki/Maros-Torda_County
# /wiki/Torda_County
# /wiki/Hungarian_language
# /wiki/Serbia
# /wiki/Memory_of_the_World_Programme
# /wiki/Russia
# /wiki/NASA_Space_Science_Data_Coordinated_Archive
# /wiki/Astronomy
# /wiki/Black-body_radiation
# /wiki/Carbon_black
# /wiki/Vulcanization
# /wiki/Airfield_rubber_removal
# /wiki/Vulcanization
# /wiki/Sulfur_vulcanization
# /wiki/Thermosetting_polymer
# /wiki/ISBN_(identifier)
# /wiki/Process_Specification_Language
# /wiki/OpenDocument
# /wiki/Microsoft
# /wiki/Windows_Server_2016
# /wiki/List_of_Microsoft_Windows_versions
# /wiki/Windows_3.0
# /wiki/XMS_memory
# /wiki/Lotus_Software
# /wiki/Lotus_Expeditor
# /wiki/Lotus_Organizer
# /wiki/ICalendar
# /wiki/MIME
# /wiki/HTML_email
# /wiki/ASCII
# /wiki/LCCN_(identifier)
# /wiki/Authority_control
# /wiki/Registration_authority
# /wiki/ISO_15707
# /wiki/British_Standard_Pipe
# /wiki/ISO/IEC_8859-15
# /wiki/H
# /wiki/Voiceless_velar_fricative
# /wiki/Danish_orthography
# /wiki/Karelian_alphabet
# /wiki/%C4%8C
# /wiki/Chocolate
# /wiki/Aristocracy
# /wiki/Karl_Ludwig_von_Haller
# /wiki/Conservatism_in_Colombia
# /wiki/Far-right_politics
# /wiki/Falangism
# /wiki/Falange_Espa%C3%B1ola_de_las_JONS_(Aut%C3%A9ntica)
# /wiki/Falangism
# /wiki/Miguel_Primo_de_Rivera
# /wiki/Ram%C3%B3n_Mar%C3%ADa_Narv%C3%A1ez
# /wiki/Spain
# /wiki/List_of_countries_and_territories_by_land_borders
# /wiki/Uganda
# /wiki/Butaleja_District
# /wiki/Districts_of_Uganda
# /wiki/Lamwo_District
# /wiki/Nwoya_District
# /wiki/Serere_District
# /wiki/Lira_District
# /wiki/Wakiso_District
# /wiki/Ssabagabo
# /wiki/Namugongo
# /wiki/Mbalwa
# /wiki/Zana,_Uganda
# /wiki/Gombe,_Wakiso,_Uganda
# /wiki/Herman_Kasekende
# /wiki/Commercial_bank
# /wiki/Wayback_Machine
# /wiki/Brewster_Kahle
# /wiki/Internet_Hall_of_Fame
# /wiki/Richard_Stallman
# /wiki/Abhay_Bhushan
# /wiki/Internet_Hall_of_Fame
# /wiki/Lifetime_achievement_award
# /wiki/Donostia_Award
# /wiki/V%C3%ADctor_Erice
# /wiki/The_Spirit_of_the_Beehive
# /wiki/John_Simon_(critic)
# /wiki/ISBN_(identifier)
# /wiki/ISO_1629
# /wiki/MPEG-4_Part_11
# /wiki/High_Efficiency_Image_File_Format
# /wiki/VP3
# /wiki/RTAudio
# /wiki/H.263
# /wiki/MPEG-4_Part_14
# /wiki/Audio_Video_Standard#Second_generation
# /wiki/WebM
# /wiki/LDAC_(codec)
# /wiki/MPEG-5
# /wiki/Comparison_of_audio_coding_formats
# /wiki/Comparison_of_video_codecs
# /wiki/Golomb_coding
# /wiki/IEEE_Transactions_on_Information_Theory
# /wiki/Information_theory
# /wiki/ISSN_(identifier)
# /wiki/ISO/IEC_15693
# /wiki/ISO/IEC_11179
# /wiki/ISO/IEC_10021
# /wiki/Trusted_Platform_Module
# /wiki/ISO_639-3
# /wiki/ISO_8501-1
# /wiki/ISO/IEC_8859-14
# /wiki/ASCII
# /wiki/Basic_Latin_(Unicode_block)
# /wiki/Old_Uyghur
# /wiki/Chuvash_language
# /wiki/Velar_consonant
# /wiki/Dental_ejective_affricate
# /wiki/Salishan_languages
# /wiki/Nahuatl
# /wiki/Doi_(identifier)
# /wiki/File_Allocation_Table
# /wiki/C_Sharp_(programming_language)
# /wiki/PDF/UA
# /wiki/ISO_7637
# /wiki/ISO/IEC_11179
# /wiki/CHILL
# /wiki/ISO_2848
# /wiki/Kappa_number
# /wiki/ISO/IEC_7811
# /wiki/126_film
# /wiki/Advanced_Photo_System
# /wiki/Nikon_Corporation#Optics
# /wiki/Tokio_Marine
# /wiki/MS%26AD_Insurance_Group
# /wiki/NEC
# /wiki/KMD_(company)
# /wiki/Denmark
# /wiki/Portuguese_Armed_Forces
# /wiki/Portuguese_architecture
# /wiki/Cividade_de_Terroso
# /wiki/Douro
# /wiki/Duruelo_de_la_Sierra
# /wiki/Spain
# /wiki/Peninsular_War
# /wiki/Convention_of_Artlenburg
# /wiki/Meyers_Konversations-Lexikon
# /wiki/Nazism
# /wiki/Bengasi_(film)
# /wiki/Guglielmo_Sinaz
# /wiki/Hands_Off_Me!
# /wiki/Safa_Palatino_Studios
# /wiki/Indiana_Production
# /wiki/List_of_Italian_films_of_1968
# /wiki/Gina_Lollobrigida
# /wiki/Claudia_Cardinale
# /wiki/One_Russian_Summer
# /wiki/Mymovies.it
# /wiki/La_Repubblica
# /wiki/Giorgio_Bocca
# /wiki/History_of_women_in_the_Italian_Resistance
# /wiki/1944
# /wiki/Patti_LaBelle
# /wiki/The_Voice_(American_TV_series)
# /wiki/CBS_Interactive
# /wiki/Nickelodeon_(Scandinavian_TV_channel)
# /wiki/MTV_Rocks_(European_TV_channel)
# /wiki/Nickelodeon_(Dutch_TV_channel)
# /wiki/Nickelodeon_(Croatian_TV_channel)
# /wiki/Nickelodeon_(Slovenian_TV_channel)
# /wiki/TMF_Flanders
# /wiki/Nickelodeon_(French_TV_channel)
# /wiki/Mediawan_Thematics
# /wiki/Game_One
# /wiki/Mangas_(TV_channel)
# /wiki/Direct_8
# /wiki/T%C3%A9l%C3%A9vision_Num%C3%A9rique_Terrestre
# /wiki/France_T%C3%A9l%C3%A9visions
# /wiki/Hoopla_(digital_media_service)
# /wiki/Streaming_media
# /wiki/MPEG-4_AVC
# /wiki/Requirements_engineering
# /wiki/Performance_engineering
# /wiki/System_lifecycle
# /wiki/Project_life_cycle
# /wiki/Arthur_David_Hall_III
# /wiki/System_of_systems_engineering
# /wiki/System_lifecycle
# /wiki/Control_engineering
# /wiki/S2CID_(identifier)
# /wiki/Chemical_patent
# /wiki/Academic_journal
# /wiki/Renaissance_humanism
# /wiki/Satan
# /wiki/Medina#Pre-Islamic_times
# /wiki/Hijrah
# /wiki/Mus%27ab_ibn_Umayr
# /wiki/Muhammad_and_the_Bible
# /wiki/Gospel_of_Barnabas
# /wiki/Irenaeus
# /wiki/Rule_of_faith
# /wiki/Catholic_Church
# /wiki/Hail_Mary
# /wiki/Giuseppe_Verdi
# /wiki/I_due_Foscari
# /wiki/The_Two_Foscari_(Byron)
# /wiki/Augusta_Leigh
# /wiki/Amelia_Osborne,_Marchioness_of_Carmarthen
# /wiki/Francis_Osborne,_1st_Baron_Godolphin
# /wiki/Member_of_Parliament_(United_Kingdom)
# /wiki/1832_United_Kingdom_general_election
# /wiki/Tories_(British_political_party)
# /wiki/Irish_Monarchist_Society
# /wiki/Irish_nationalism
# /wiki/Education_in_Northern_Ireland
# /wiki/List_of_High_Kings_of_Ireland
# /wiki/Irish_stepdance
# /wiki/Musicality
# /wiki/Spotting_(dance_technique)
# /wiki/Mirror%27s_Edge
# /wiki/Will_Wright_(game_designer)
# /wiki/Martin_Campbell
# /wiki/Sam_Mendes
# /wiki/Douglas_Wick
# /wiki/Alejandro_Gonz%C3%A1lez_I%C3%B1%C3%A1rritu
# /wiki/Glen_Robinson_(visual_effects)
# /wiki/Richard_Edlund
# /wiki/Total_Recall_(1990_film)
# /wiki/Aljean_Harmetz
# /wiki/Dashiell_Hammett
# /wiki/Philadelphia
# /wiki/Amtrak
# /wiki/Silver_Star_(Amtrak_train)
# /wiki/Crescent_(train)
# /wiki/Northeast_Corridor
# /wiki/High-speed_rail_in_China
# /wiki/Shanghai_Pudong_International_Airport
# /wiki/Narita_International_Airport
# /wiki/Kei%C5%8D_New_Line
# /wiki/Tokyo_Metro_Hanz%C5%8Dmon_Line
# /wiki/Toei_Subway
# /wiki/Inba-Nihon-Idai_Station
# /wiki/Narita_Yukawa_Station
# /wiki/Narita_Airport_Terminal_1_Station
# /wiki/Shiishiba_Station
# /wiki/Japan_National_Railways
# /wiki/Kinki_Sharyo
# /wiki/Ma_On_Shan_line
# /wiki/West_Rail_line
# /wiki/Tuen_Ma_line
# /wiki/Kwun_Tong_line
# /wiki/Tseung_Kwan_O_line
# /wiki/Tseung_Kwan_O
# /wiki/Lands_Department
# /wiki/Basic_Law_of_Hong_Kong
# /wiki/Innovation,_Technology_and_Industry_Bureau
# /wiki/Elections_in_Hong_Kong
# /wiki/Kowloon_West_New_Dynamic
# /wiki/United_front_in_Hong_Kong
# /wiki/Deng_Xiaoping_Theory
# /wiki/Wayback_Machine
# /wiki/CSS
# /wiki/SeaMonkey
# /wiki/Floorp
# /wiki/Timberwolf_(web_browser)
# /wiki/Sam440ep
# /wiki/Amiga_600
# /wiki/Joystick
# /wiki/TNK_III
# /wiki/Arcade_video_game
# /wiki/1999_in_video_games
# /wiki/Open_world
# /wiki/A_Short_Hike
# /wiki/Inscryption
# /wiki/Bad_Milk
# /wiki/Minecraft
# /wiki/C418
# /wiki/Black_rights
# /wiki/Timeline_of_the_civil_rights_movement
# /wiki/Genius_(American_TV_series)
# /wiki/Griffin_Matthews
# /wiki/IMDb_(identifier)
# /wiki/BBC
# /wiki/BBC_Radio_Jersey
# /wiki/BBC_Radio_Cumbria
# /wiki/Timeline_of_BBC_Local_Radio
# /wiki/BBC_Radio_Wolverhampton
# /wiki/BBC_Radio_Surrey
# /wiki/Medium_wave
# /wiki/Very-high-energy_gamma_ray
# /wiki/Super_high_frequency
# /wiki/Ka_band
# /wiki/ACTS_Gigabit_Satellite_Network
# /wiki/Lockheed_Martin
# /wiki/Lockheed_L-749_Constellation
# /wiki/List_of_Lockheed_Constellation_operators
# /wiki/Lockheed_L-1249_Super_Constellation
# /wiki/Lockheed_XF-104_Starfighter
# /wiki/Landing_gear
# /wiki/Arado_Ar_232
# /wiki/Heinkel_He_64
# /wiki/Dornier_Do_335
# /wiki/Fighter-bomber
# /wiki/Gunship
# /wiki/CASA/IPTN_CN-235
# /wiki/Yemen
# /wiki/Had%C4%B1m_Suleiman_Pasha
# /wiki/Mehmed_Said_Pasha
# /wiki/K%C3%B6se_Bahir_Mustafa_Pasha
# /wiki/Syria
# /wiki/History_of_Christianity
# /wiki/Bramante
# /wiki/Hugh_Chisholm
# /wiki/Arthur_Twining_Hadley
# /wiki/Luzon_Buritt_Morris
# /wiki/Suffield_Academy
# /wiki/Squash_(sport)
# /wiki/Nancy_Cave
# /wiki/Cecily_Fenwick
# /wiki/Michelle_Martin
# /wiki/Women%27s_Hong_Kong_squash_Open_2011
# /wiki/Malaysia
# /wiki/Kyrgyzstan
# /wiki/Sverdlov_District,_Bishkek
# /wiki/Districts_of_Kyrgyzstan
# /wiki/LGBT_rights_in_Kyrgyzstan
# /wiki/LGBT_rights_in_Lebanon
# /wiki/LGBT_rights_in_Taiwan
# /wiki/Deforestation_in_Taiwan
# /wiki/Government_of_the_Republic_of_China
# /wiki/Control_Yuan
# /wiki/Democratic_Progressive_Party
# /wiki/Hsiao_Bi-khim
# /wiki/John_Wu_(politician)
# /wiki/Lee_Yen-hsiu
# /wiki/Legislative_Yuan
# /wiki/Control_Yuan
# /wiki/Judicial_Yuan
# /wiki/Judiciary_of_Pakistan
# /wiki/Government_of_Punjab,_Pakistan
# /wiki/Sheikhupura_District
# /wiki/Mianwali_Division
# /wiki/Sukkur_Division
# /wiki/Sindh
# /wiki/Pakistani_rupee
# /wiki/Matale_Rebellion
# /wiki/Campaign_of_Danture
# /wiki/Lamprais
# /wiki/Suriya-Mal_Movement
# /wiki/List_of_riots_in_Sri_Lanka
# /wiki/1953_Ceylonese_Hartal
# /wiki/Hartal
# /wiki/Barbara_D._Metcalf
# /wiki/Bernard_Bailyn
# /wiki/Barbara_D._Metcalf
# /wiki/Mary_Beth_Norton
# /wiki/Charles_Howard_McIlwain
# /wiki/David_Herlihy
# /wiki/George_Park_Fisher
# /wiki/Caroline_Walker_Bynum
# /wiki/Charles_McLean_Andrews
# /wiki/Jan_E._Goldstein
# /wiki/Evarts_Boutell_Greene
# /wiki/Natalie_Zemon_Davis
# /wiki/ISSN_(identifier)
# /wiki/Document_Style_Semantics_and_Specification_Language
# /wiki/126_film
# /wiki/ISO_2015
# /wiki/ISO_9000
# /wiki/Topic_map
# /wiki/IEC_61030
# /wiki/IEC_62325
# /wiki/IEC_63110
# /wiki/Charging_station
# /wiki/Tesla_Supercharger
# /wiki/Electric_car
# /wiki/Rear-engine,_front-wheel-drive_layout
# /wiki/Two-stroke_engine
# /wiki/Autofeather
# /wiki/Supercharger
# /wiki/Mercedes_(marque)
# /wiki/Mercedes-Benz_India
# /wiki/Mercedes-Benz_Argentina
# /wiki/General_Motors_de_Argentina
# /wiki/San_Telmo,_Buenos_Aires
# /wiki/Ministry_of_Agriculture_(Argentina)
# /wiki/National_Autonomist_Party
# /wiki/Broad_Progressive_Front_(Argentina)
# /wiki/Neighbourhood_Action_Movement
# /wiki/New_Party_(Corrientes)
# /wiki/Civic_Front_for_Santiago
# /wiki/Socialist_Left_(Argentina)
# /wiki/San_Luis_Province
# /wiki/Villa_General_Roca
# /wiki/Provinces_of_Argentina
# /wiki/We_Do_for_C%C3%B3rdoba
# /wiki/Neighbourhood_Action_Movement
# /wiki/Localism_(politics)
# /wiki/Theocracy
# /wiki/Pakistani_nationalism
# /wiki/Gunpowder
# /wiki/Wujing_Zongyao
# /wiki/Yaozhou_ware
# /wiki/Jizhou_ware
# /wiki/Jessica_Rawson
# /wiki/Wang_Gungwu
# /wiki/Australian_National_University
# /wiki/Zhejiang_University
# /wiki/Sir_Run_Run_Shaw_Hospital
# /wiki/List_of_presidents_of_Zhejiang_University
# /wiki/Zheng_Xiaocang
# /wiki/Southeast_University
# /wiki/Jiming_Temple
# /wiki/Taiping_Rebellion
# /wiki/Han_Chinese
# /wiki/Wayback_Machine
# /wiki/List_of_digital_preservation_initiatives
# /wiki/National_Library_of_Australia
# /wiki/Burke_and_Wills_expedition
# /wiki/Terence_Rattigan
# /wiki/Pauline_Jameson
# /wiki/Ian_Richardson
# /wiki/List_of_House_of_Cards_trilogy_characters
# /wiki/Margaret_Thatcher
# /wiki/Cultural_depictions_of_Margaret_Thatcher
# /wiki/The_Blues_Band
# /wiki/Maggie%27s_Farm
# /wiki/On_a_Night_Like_This_(Bob_Dylan_song)
# /wiki/Dylan_(1973_album)
# /wiki/Joan_Baez
# /wiki/The_History_of_Rock_%27n%27_Roll
# /wiki/Seven_Ages_of_Rock
# /wiki/Ozzy_Osbourne
# /wiki/Yesterday_(TV_channel)
# /wiki/The_Sunday_People
# /wiki/Lloyd_Embley
# /wiki/Alison_Phillips
# /wiki/Brexit_negotiations
# /wiki/Spain%E2%80%93United_Kingdom_relations
# /wiki/Bernardo_de_Galvez
# /wiki/Juan_de_Palafox_y_Mendoza
# /wiki/Juan_Ortega_y_Monta%C3%B1%C3%A9s
# /wiki/Ferdinand_VI_of_Spain
# /wiki/Ferdinand_VI_of_Spain
# /wiki/Isabella_II
# /wiki/Ferdinand_II_of_Aragon
# /wiki/Televisi%C3%B3n_Espa%C3%B1ola
# /wiki/Israeli_Educational_Television
# /wiki/Televisi%C3%B3n_P%C3%BAblica
# /wiki/All-Russia_State_Television_and_Radio_Broadcasting_Company
# /wiki/Udru%C5%BEenje_javnih_radija_i_televizija
# /wiki/All_India_Radio
# /wiki/Antonio_Meucci
# /wiki/Vito_Fossella
# /wiki/Peter_King_(American_politician)
# /wiki/113th_United_States_Congress
# /wiki/Terri_Sewell
# /wiki/Max_Miller_(politician)
# /wiki/Lawrence_T._Neal
# /wiki/George_E._Seney
# /wiki/Bob_Gibbs
# /wiki/Anthony_Gonzalez_(politician)
# /wiki/Cydnor_B._Tompkins
# /wiki/Lorenzo_Danford
# /wiki/Jonathan_T._Updegraff
# /wiki/John_Goode_(Virginia_politician)
# /wiki/Charles_Fahy
# /wiki/United_States_Court_of_Appeals_for_the_District_of_Columbia_Circuit
# /wiki/Dorothy_Wright_Nelson
# /wiki/United_States_Court_of_Appeals_for_the_Ninth_Circuit
# /wiki/Appellate_jurisdiction
# /wiki/New_Jersey_Court_of_Errors_and_Appeals
# /wiki/Courts_of_New_Jersey
# /wiki/United_States_Court_of_Appeals_for_the_Fourth_Circuit
# /wiki/United_States_District_Court_for_the_Southern_District_of_Iowa
# /wiki/United_States_District_Court_for_the_District_of_Hawaii
# /wiki/Kingman_Reef
# /wiki/Puerto_Rico
# /wiki/Farruko
# /wiki/Travis_Scott
# /wiki/Young_Thug
# /wiki/Anderson_.Paak
# /wiki/Black_Radio_III
# /wiki/Tiffany_Gouch%C3%A9
# /wiki/Lalah_Hathaway
# /wiki/Lalah_Hathaway_(album)
# /wiki/Angela_Winbush
# /wiki/Los_Angeles_Times
# /wiki/El_Segundo_High_School
# /wiki/Blackboard_Jungle
# /wiki/ISBN_(identifier)
# /wiki/VD_16
# /wiki/Library
# /wiki/Book_size
# /wiki/Book_burning
# /wiki/List_of_book-burning_incidents
# /wiki/Ancient_Greek_philosophy
# /wiki/Roman_Empire
# /wiki/Roman_engineering
# /wiki/Lucian
# /wiki/Middle_Aramaic
# /wiki/Christian_Palestinian_Aramaic
# /wiki/Alain_Desreumaux
# /wiki/Epigraphy
# /wiki/Archaeology_(magazine)
# /wiki/Archaeological_Institute_of_America
# /wiki/Boston
# /wiki/Robert_Gould_Shaw_Memorial
# /wiki/Statue_of_William_Francis_Bartlett
# /wiki/Equestrian_statue_of_Joseph_Hooker
# /wiki/The_Partisans_(sculpture)
# /wiki/Boston_Art_Commission
# /wiki/The_Partisans_(sculpture)
# /wiki/Statue_of_Christopher_Columbus_(Beacon_Hill,_Boston)
# /wiki/Statue_of_William_Prescott
# /wiki/William_Wetmore_Story
# /wiki/Harvard_University
# /wiki/Baseball
# /wiki/Pioneer_League_(baseball)
# /wiki/Ogden_Reds
# /wiki/Ken_Polivka
# /wiki/Win%E2%80%93loss_record_(pitching)
# /wiki/Home_run
# /wiki/Hank_Aaron
# /wiki/ESPN_Classic
# /wiki/Channel_drift
# /wiki/CTV_Drama_Channel
# /wiki/BravoFACT
# /wiki/CKMF-FM
# /wiki/750_Burrard_Street
# /wiki/Independent_station_(North_America)
# /wiki/KCAL-TV
# /wiki/The_Nest_(TV_network)
# /wiki/Charleston,_South_Carolina
# /wiki/John_Locke
# /wiki/East_Florida
# /wiki/Florida_Man
# /wiki/List_of_regions_of_the_United_States#Florida
# /wiki/Same-sex_marriage_law_in_the_United_States_by_state
# /wiki/Same-sex_marriage_in_Illinois
# /wiki/Same-sex_marriage_in_Mississippi
# /wiki/Randy_G._Pierce
# /wiki/Greene_County,_Mississippi
# /wiki/1932_United_States_presidential_election_in_Mississippi
# /wiki/2012_United_States_House_of_Representatives_elections_in_Mississippi
# /wiki/2012_United_States_House_of_Representatives_election_ratings
# /wiki/Scott_Rigell
# /wiki/Scott_Taylor_(politician)
# /wiki/Andrew_Moore_(politician)
# /wiki/David_Gardiner_Tyler
# /wiki/Richard_Alsop_Wise
# /wiki/John_Morrow_(Virginia_politician)
# /wiki/James_Stephenson_(congressman)
# /wiki/United_States_House_of_Representatives
# /wiki/2017_United_States_state_legislative_elections
# /wiki/New_Hampshire_Senate
# /wiki/South_Dakota_Senate
# /wiki/McCook_County,_South_Dakota
# /wiki/UTC%E2%88%925
# /wiki/Morgan_County,_Tennessee
# /wiki/Race_(United_States_Census)
# /wiki/Gabonese_Americans
# /wiki/List_of_Singaporean_Americans
# /wiki/West_Africans_in_the_United_States
# /wiki/Eritrean_Americans
# /wiki/Chumash_people
# /wiki/Takic_languages
# /wiki/Northern_Paiute_language
# /wiki/Back_vowel
# /wiki/Labial%E2%80%93retroflex_consonant
# /wiki/Glottalization
# /wiki/Tongan_language
# /wiki/Language_death
# /wiki/Scottish_Gaelic
# /wiki/History_of_Scottish_devolution
# /wiki/Agriculture_in_Scotland
# /wiki/Union_dividend
# /wiki/Revenue_Scotland
# /wiki/North_Sea_oil
# /wiki/Agriculture_in_Scotland
# /wiki/National_Museum_of_Rural_Life
# /wiki/Flail_(agriculture)
# /wiki/Rice
# /wiki/Stenchaetothrips_biformis
# /wiki/Taxonomy_(biology)
# /wiki/Cladistics
# /wiki/Charaka_Samhita
# /wiki/Isha_Upanishad
# /wiki/Aranyaka
# /wiki/Kamasutra
# /wiki/ISBN_(identifier)
# /wiki/Wayback_Machine
# /wiki/Canadian_Libraries_(collection)
# /wiki/Internet_Archive#Text_collection
# /wiki/PC_game
# /wiki/ASCII_Entertainment
# /wiki/Spike_(company)
# /wiki/PlayStation_2
# /wiki/Sony_Xperia
# /wiki/GSM
# /wiki/Stream_cipher
# /wiki/Exclusive-or
# /wiki/Java_(programming_language)
# /wiki/Scala_(programming_language)
# /wiki/Actor_model
# /wiki/Wayback_Machine
# /wiki/United_States_District_Court_for_the_District_of_Colorado
# /wiki/Durango,_Colorado
# /wiki/Cheyenne_County,_Colorado
# /wiki/South_Central_Colorado_Urban_Area
# /wiki/Colorado
# /wiki/Front_Range_Urban_Corridor
# /wiki/Fremont_County,_Colorado
# /wiki/Daylight_saving_time
# /wiki/Summer_time_in_Europe#Future
# /wiki/Time_in_Georgia_(country)
# /wiki/Armenia_Time
# /wiki/Georgia_Time
# /wiki/Eastern_Time_Zone
# /wiki/New_York_(state)
# /wiki/List_of_largest_LGBT_events
# /wiki/Rome
# /wiki/Piazza
# /wiki/Tiny-house_movement
# /wiki/Frugality
# /wiki/Dhrti
# /wiki/Hinduism
# /wiki/Doi_(identifier)
# /wiki/Torx
# /wiki/Hex_key
# /wiki/Plunger
# /wiki/Pressure
# /wiki/Pressure_head
# /wiki/Water
# /wiki/Crystal_structure
# /wiki/Hall%E2%80%93Petch
# /wiki/Mild_steel
# /wiki/Strength_of_materials
# /wiki/Universal_testing_machine
# /wiki/Non-ferrous_metal
# /wiki/Cerium
# /wiki/Chalcogen
# /wiki/Thallium(III)_oxide
# /wiki/Uranium_dioxide
# /wiki/International_Chemical_Identifier
# /wiki/Doi_(identifier)
# /wiki/ISO_31-10
# /wiki/Common_Logic
# /wiki/ISO_19092-1
# /wiki/International_Standard_Atmosphere
# /wiki/ISO_217
# /wiki/Prolog
# /wiki/ISO_8583
# /wiki/ISO_10628
# /wiki/Rectangular_Micro_QR_Code
# /wiki/ISO/IEC_27001
# /wiki/ALGOL_60
# /wiki/Robert_W._Floyd
# /wiki/Peter_Naur
# /wiki/ALGOL_68
# /wiki/Font
# /wiki/Gaelic_type
# /wiki/ISSN_(identifier)
# /wiki/ISO_50001
# /wiki/ISO_3166
# /wiki/Latin_script
# /wiki/Louis_Braille
# /wiki/Panth%C3%A9on
# /wiki/Rue_Montorgueil
# /wiki/1st_arrondissement_of_Paris
# /wiki/Saint-Germain_l%27Auxerrois
# /wiki/Notre-Dame-de-Bonne-Nouvelle
# /wiki/Neoclassical_architecture
# /wiki/Ancient_Rome
# /wiki/Papal_States
# /wiki/Lateran_Treaty
# /wiki/Fourth_Council_of_the_Lateran
# /wiki/Crucifixion_of_Jesus
# /wiki/Longinus
# /wiki/Jude_the_Apostle
# /wiki/Ananias_and_Sapphira
# /wiki/Barabbas
# /wiki/Junia_(New_Testament_person)
# /wiki/Four_Evangelists
# /wiki/Crosses_in_heraldry
# /wiki/St._Florian
# /wiki/Florian_Gate
# /wiki/Krak%C3%B3w
# /wiki/Magdeburg
# /wiki/Nordhausen,_Thuringia
# /wiki/2011_EU_census
# /wiki/Member_state_of_the_European_Union
# /wiki/Government_procurement_in_the_European_Union
# /wiki/Rotenburg_(W%C3%BCmme)
# /wiki/Hemsb%C3%BCnde
# /wiki/Wilstedt
# /wiki/Geographic_coordinate_system
# /wiki/Canary_Islands
# /wiki/Alegranza
# /wiki/Chinijo_Archipelago
# /wiki/Smithsonian_Institution
# /wiki/African_American_Civil_War_Memorial_Museum
# /wiki/National_Mall_and_Memorial_Parks
# /wiki/Second_Division_Memorial
# /wiki/United_States_Army
# /wiki/Pancho_Villa
# /wiki/Chihuahua,_Chihuahua
# /wiki/Chihuahua_(state)
# /wiki/Wayback_Machine
# /wiki/Hachette_v._Internet_Archive
# /wiki/Democracy_Now!#Democracy_Now!_collection_at_the_Internet_Archive
# /wiki/Radio_Exterior
# /wiki/Radio_Romania_International
# /wiki/Outline_of_telecommunication
# /wiki/Beacon
# /wiki/John_Bardeen
# /wiki/Frequency-division_multiplexing
# /wiki/Information_Age
# /wiki/Planar_process
# /wiki/Doi_(identifier)
# /wiki/Scientific_literature
# /wiki/Bibliometrics
# /wiki/ORCID
# /wiki/Erratum
# /wiki/Canons_of_page_construction
# /wiki/Book_design#Body_matter
# /wiki/Book_cover
# /wiki/Introduction_(writing)
# /wiki/Typeface
# /wiki/Descender
# /wiki/List_of_typographical_symbols_and_punctuation_marks
# /wiki/Z
# /wiki/Voiceless_retroflex_fricative
# /wiki/Khanty_language
# /wiki/Ob_(river)
# /wiki/South_Caucasus
# /wiki/MENASA
# /wiki/Doi_(identifier)
# /wiki/Unified_Modeling_Language
# /wiki/Software_incompatibility
# /wiki/Computer_program
# /wiki/ISBN_(identifier)
# /wiki/Textbook
# /wiki/Evolution
# /wiki/S2CID_(identifier)
# /wiki/Poster_session
# /wiki/Abstract_management
# /wiki/Poster_session
# /wiki/Doi_(identifier)
# /wiki/MPEG-1
# /wiki/Basic_rate_interface
# /wiki/Bit_rate
# /wiki/Differential_pulse-code_modulation
# /wiki/Wavelet_transform
# /wiki/Run-length_encoding
# /wiki/G.723.1
# /wiki/Lossy_compression
# /wiki/YIQ
# /wiki/HCL_color_space
# /wiki/ICtCp
# /wiki/LMS_color_space
# /wiki/Rec._2020
# /wiki/8K_resolution#Resolutions
# /wiki/Non-linear_editing_system
# /wiki/Moviola
# /wiki/Metro-Goldwyn-Mayer
# /wiki/MGM_Records
# /wiki/Donny_%26_Marie_Osmond
# /wiki/We_Can_Make_it_Together
# /wiki/1971_in_music
# /wiki/The_Family_(Mashmakhan_album)
# /wiki/Psychedelic_rock
# /wiki/Humphry_Osmond
# /wiki/Psychotomimetic
# /wiki/JWH-182
# /wiki/AM404
# /wiki/Nalbuphine
# /wiki/Tenoxicam
# /wiki/Tiaprofenic_acid
# /wiki/Oxicam
# /wiki/Difenamizole
# /wiki/Metopon
# /wiki/Molar_mass
# /wiki/Vapour_density
# /wiki/Vapour
# /wiki/Liquid_crystal
# /wiki/S2CID_(identifier)
# /wiki/Chapter_(books)
# /wiki/Miniature_book
# /wiki/Library_of_Congress
# /wiki/Public_domain
# /wiki/Publici_juris
# /wiki/Law
# /wiki/Revolution
# /wiki/ISBN_(identifier)
# /wiki/MPEG-21
# /wiki/ISO/IEC_27002
# /wiki/MPEG-2
# /wiki/%CE%9C-law_algorithm
# /wiki/Shannon%E2%80%93Fano%E2%80%93Elias_coding
# /wiki/Image_resolution
# /wiki/LaserDisc
# /wiki/Bugsy
# /wiki/Gene_Krupa
# /wiki/Times_Square
# /wiki/Thirteenth_Avenue_(Manhattan)
# /wiki/Great_Jones_Street
# /wiki/Bracetti_Plaza
# /wiki/Burp_Castle
# /wiki/Anthos_(restaurant)
# /wiki/Philippine_Center
# /wiki/Lexington_Avenue/51st_Street_station
# /wiki/East_River_Greenway
# /wiki/Mission_of_Our_Lady_of_Loreto
# /wiki/St._Sylvia%27s_Church_(Tivoli,_New_York)
# /wiki/St._Mary%27s_Church_(Poughkeepsie,_New_York)
# /wiki/Church_of_Our_Lady_of_Sorrows_(New_York_City)
# /wiki/St._Joan_of_Arc%27s_Church_(Bronx)
# /wiki/Roman_Catholic_Archdiocese_of_New_York
# /wiki/Jerome
# /wiki/Writing_material
# /wiki/Cave_painting
# /wiki/Beadwork
# /wiki/Adze
# /wiki/Spear-thrower
# /wiki/Upper_Paleolithic
# /wiki/Clava_cairn
# /wiki/Ness_of_Brodgar
# /wiki/Cardium_pottery
# /wiki/Pictogram
# /wiki/Patent_drawing
# /wiki/David_McCandless
# /wiki/Statistical_graphics
# /wiki/Average_absolute_deviation
# /wiki/Ljung%E2%80%93Box_test
# /wiki/Psychometrics
# /wiki/Test_validity
# /wiki/Education_in_Sudan
# /wiki/Sudan_University_of_Science_and_Technology
# /wiki/Technology
# /wiki/Doi_(identifier)
# /wiki/Flowchart
# /wiki/Graphical_Kernel_System
# /wiki/ISO_13490
# /wiki/JFFS
# /wiki/List_of_file_systems
# /wiki/RozoFS
# /wiki/Distributed_file_system
# /wiki/Write_Ahead_Physical_Block_Logging
# /wiki/Btrfs
# /wiki/File_change_log
# /wiki/Web_crawler
# /wiki/Heritrix
# /wiki/Free_software_license
# /wiki/End-of-life_product
# /wiki/Product_life_cycle_management
# /wiki/Product_lifecycle
# /wiki/Office_management
# /wiki/Partnership
# /wiki/Sales_management
# /wiki/S2CID_(identifier)
# /wiki/OCLC_(identifier)
# /wiki/Ohio_Secretary_of_State
# /wiki/JD_Vance
# /wiki/Elizabeth_Warren
# /wiki/Consumer_Financial_Protection_Bureau
# /wiki/Federal_Home_Loan_Banks
# /wiki/Presidential_transition_of_Franklin_D._Roosevelt
# /wiki/Frank_C._Walker
# /wiki/List_of_presidents_of_the_United_States
# /wiki/Doi_(identifier)
# /wiki/ISO_7736
# /wiki/ISO_7200
# /wiki/ISO_22000
# /wiki/Light_pollution
# /wiki/Overillumination
# /wiki/Light_pollution_in_Hong_Kong
# /wiki/Lights_Out_Hong_Kong
# /wiki/Donald_Tsang
# /wiki/Henry_Tang
# /wiki/Li_Ka_Shing
# /wiki/Refugees_in_Hong_Kong
# /wiki/Ukrainians_in_Hong_Kong
# /wiki/Ukrainian_Canadians
# /wiki/Public_holidays_in_Ukraine
# /wiki/Unification_Act
# /wiki/Leonid_Kuchma
# /wiki/Donetsk_Oblast
# /wiki/Donetsk
# /wiki/ATP_Challenger_Series
# /wiki/Aberto_de_Florian%C3%B3polis
# /wiki/Baden_Open
# /wiki/Trofeo_Citt%C3%A0_di_Brescia
# /wiki/Lubbock_Challenger
# /wiki/Tempe_Challenger
# /wiki/Challenger_La_Manche
# /wiki/Cary_Tennis_Classic
# /wiki/Bendigo_International_(tennis)
# /wiki/Marcelo_Ar%C3%A9valo
# /wiki/1990_French_Open_%E2%80%93_Men%27s_doubles
# /wiki/United_States
# /wiki/Ancestral_Puebloans
# /wiki/Chanunpa
# /wiki/Ocmulgee_Mounds_National_Historical_Park
# /wiki/United_States_Department_of_the_Interior
# /wiki/Mexican%E2%80%93American_War
# /wiki/Texas_annexation
# /wiki/Tennessee%27s_9th_congressional_district
# /wiki/2010_United_States_House_of_Representatives_elections_in_Tennessee
# /wiki/2010_United_States_House_of_Representatives_elections_in_Missouri
# /wiki/Republican_Party_(United_States)
# /wiki/JSTOR_(identifier)
# /wiki/Wayback_Machine
# /wiki/EchoStar
# /wiki/Briz-M
# /wiki/Ekspress_(satellite_bus)
# /wiki/Soyuz-2.1b
# /wiki/Next_Generation_Launch_Vehicle
# /wiki/Safir_(rocket)
# /wiki/Semnan_Space_Center
# /wiki/Base_603
# /wiki/Space_%26_Upper_Atmosphere_Research_Commission
# /wiki/Intersputnik
# /wiki/KazCosmos
# /wiki/State_Space_Agency_of_Ukraine
# /wiki/Oleksandr_Zinchenko_(politician)
# /wiki/Patronymic
# /wiki/Afghan_name
# /wiki/Ecclesiastical_titles_and_styles
# /wiki/Subsidiary_title
# /wiki/Definite_article
# /wiki/Postpositive_adjective
# /wiki/Letters_patent
# /wiki/Plurale_tantum
# /wiki/Jeans
# /wiki/Genoese_navy
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Whirlpool_(hash_function)
# /wiki/LSH_(hash_function)
# /wiki/MASH-1
# /wiki/Scrypt
# /wiki/Decentralized_finance#Decentralized_exchanges
# /wiki/Polkadot_(cryptocurrency)
# /wiki/Proof_of_work
# /wiki/Cryptocurrency_in_Nigeria
# /wiki/Decentralized_finance#Decentralized_exchanges
# /wiki/OneCoin
# /wiki/Europol
# /wiki/Law_enforcement_in_Hungary
# /wiki/Law_enforcement_in_France
# /wiki/Republican_Guard_(France)
# /wiki/Saint-Ambroise,_Paris
# /wiki/Gothic_architecture
# /wiki/List_of_Catholic_philosophers_and_theologians
# /wiki/Catholic_moral_theology
# /wiki/Thomas_Aquinas
# /wiki/Bede
# /wiki/%C3%86thelberht_II_of_East_Anglia
# /wiki/Luckington
# /wiki/Basil_Harwood
# /wiki/Church_of_St_Barnabas,_Pimlico
# /wiki/Architect
# /wiki/General_contractor
# /wiki/Contract_management
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Dialog_(online_database)
# /wiki/Roger_K._Summit
# /wiki/European_Space_Agency
# /wiki/GIOVE-B
# /wiki/Soil_Moisture_and_Ocean_Salinity
# /wiki/Sentinel-3A
# /wiki/European_Remote-Sensing_Satellite
# /wiki/Envisat
# /wiki/Earth_observation_satellite
# /wiki/Space_Race
# /wiki/Sino-Albanian_split
# /wiki/Marxism%E2%80%93Leninism%E2%80%93Maoism
# /wiki/Communism
# /wiki/Tyranny_of_the_majority
# /wiki/Social_proof
# /wiki/Doi_(identifier)
# /wiki/On-board_diagnostics
# /wiki/Authentication
# /wiki/Botnet
# /wiki/Eavesdropping
# /wiki/Industrial_espionage
# /wiki/ISBN_(identifier)
# /wiki/ISO_22301
# /wiki/Web_Content_Accessibility_Guidelines
# /wiki/Hole_punch
# /wiki/Film_speed
# /wiki/ISO_15924
# /wiki/Canadian_Aboriginal_syllabics
# /wiki/Inuktitut
# /wiki/Utkuhiksalik
# /wiki/I%C3%B1upiaq_language
# /wiki/Kaktovik_numerals
# /wiki/Quater-imaginary_base
# /wiki/Knuth%E2%80%93Bendix_completion_algorithm
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_8859-7
# /wiki/Delta_(letter)
# /wiki/Deletion_(genetics)
# /wiki/Chromosomal_translocation
# /wiki/PMID_(identifier)
# /wiki/Scopus
# /wiki/Poster_session
# /wiki/Review_article
# /wiki/Research#Forms_of_research
# /wiki/Historical_method
# /wiki/Habsburg_myth
# /wiki/Porter%E2%80%93MacKenzie_debate
# /wiki/Industrial_Revolution
# /wiki/Craiova_Group
# /wiki/Belgrade
# /wiki/Ni%C5%A1
# /wiki/City_Assembly_of_Ni%C5%A1
# /wiki/Dragan_Mili%C4%87
# /wiki/Decentralization
# /wiki/Ecopreneurship
# /wiki/Syndicalism
# /wiki/Participatory_economics
# /wiki/Takis_Fotopoulos
# /wiki/Serge_Latouche
# /wiki/Mouvement_Anti-Utilitariste_dans_les_Sciences_Sociales
# /wiki/Thomas_Paine
# /wiki/Liberalism_in_Greece
# /wiki/Lajos_Kossuth
# /wiki/Gibraltar
# /wiki/Languages_of_Gibraltar
# /wiki/Vernacular
# /wiki/Stojan_Novakovi%C4%87
# /wiki/Milan_Piro%C4%87anac
# /wiki/Milan_I_of_Serbia
# /wiki/Order_of_Osmanieh
# /wiki/Ottoman_Empire
# /wiki/Zand_dynasty
# /wiki/ISBN_(identifier)
# /wiki/Advance_copy
# /wiki/Book_cover
# /wiki/Addendum#In_books
# /wiki/Bookbinding
# /wiki/Chemical_milling
# /wiki/Piece_work
# /wiki/Industrial_Revolution
# /wiki/Economy_of_Syria
# /wiki/Economic_liberalization
# /wiki/International_Monetary_Fund
# /wiki/List_of_countries_by_aluminium_exports
# /wiki/Ruthenium#Production
# /wiki/Group_12_element
# /wiki/Siberia
# /wiki/Barley
# /wiki/Barleycorn_(unit)
# /wiki/Long_hundred
# /wiki/120_(number)
# /wiki/451_(number)
# /wiki/109_(number)
# /wiki/252_(number)
# /wiki/689_(number)
# /wiki/909_(number)
# /wiki/500_(number)
# /wiki/679_(number)
# /wiki/251_(number)
# /wiki/204_(number)
# /wiki/338_(number)
# /wiki/546_(number)
# /wiki/Binary_number
# /wiki/PMC_(identifier)
# /wiki/List_of_open-source_health_software
# /wiki/National_public_health_institutes
# /wiki/Chinese_Center_for_Disease_Control_and_Prevention
# /wiki/Disease_surveillance_in_China
# /wiki/Ministry_(government_department)
# /wiki/Prime_minister
# /wiki/Ministry_of_trade_and_industry
# /wiki/Ministry_of_Foreign_Trade_(Soviet_Union)
# /wiki/List_of_heads_of_state_of_the_Soviet_Union
# /wiki/List_of_Russian_electrical_engineers
# /wiki/Boris_Borisovich_Galitzine
# /wiki/Naval_Cadet_Corps_(Russia)
# /wiki/Kuznetsov_Naval_Academy
# /wiki/Georgy_Stepanov
# /wiki/Imperial_Russian_Navy
# /wiki/Russian_Navy
# /wiki/Syria
# /wiki/Human_rights_in_Syria
# /wiki/Deir_ez-Zor_offensive_(2016)
# /wiki/Timeline_of_the_Syrian_civil_war
# /wiki/Operation_al-Shabah
# /wiki/August_2017_Brussels_attack
# /wiki/2003_Istanbul_bombings
# /wiki/List_of_terrorist_incidents_in_France
# /wiki/Time_(magazine)
# /wiki/Osama_bin_Laden
# /wiki/Sayyid_Qutb
# /wiki/Soviet%E2%80%93Afghan_War
# /wiki/1973_Afghan_coup_d%27%C3%A9tat
# /wiki/Bangladesh_Liberation_War
# /wiki/History_of_Solidarity
# /wiki/Bougainville_conflict
# /wiki/Shareholder
# /wiki/Shareholders%27_agreement
# /wiki/Bribe
# /wiki/Italy
# /wiki/Scepter
# /wiki/Eagle
# /wiki/Ayres%27s_hawk-eagle
# /wiki/Bird_of_prey
# /wiki/Galapagos_hawk
# /wiki/Darwin%27s_finches
# /wiki/Elephant_bird
# /wiki/Silurian
# /wiki/Doi_(identifier)
# /wiki/Software_maintenance
# /wiki/IEEE_802.11-1997
# /wiki/Infrared
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Recommended_retail_price
# /wiki/Manufacturer
# /wiki/Anthropocene
# /wiki/Scientific_community
# /wiki/Philosophy_of_science
# /wiki/Isaac_Newton
# /wiki/Visible_spectrum
# /wiki/Color_vision
# /wiki/Photopigment
# /wiki/Phycobilin
# /wiki/Bacteriochlorin
# /wiki/Cyanocobalamin
# /wiki/Manganese
# /wiki/ISBN_(identifier)
# /wiki/ISO_668
# /wiki/ISO_15398
# /wiki/Document_Style_Semantics_and_Specification_Language
# /wiki/List_of_ISO_standards
# /wiki/File_Allocation_Table
# /wiki/DR-DOS
# /wiki/Comparison_of_DOS_operating_systems
# /wiki/Caldera_OpenDOS_7.01
# /wiki/4DOS_8.00
# /wiki/Freeware
# /wiki/Storage_media
# /wiki/Data_communication
# /wiki/Transfer_rate
# /wiki/Prefix_code
# /wiki/Pyramid_(image_processing)
# /wiki/Feature_(computer_vision)
# /wiki/Template_matching
# /wiki/Convolutional_neural_network
# /wiki/Backpropagation
# /wiki/Occam_learning
# /wiki/OPTICS_algorithm
# /wiki/Linear_discriminant_analysis
# /wiki/Fourier_analysis
# /wiki/Topological_group
# /wiki/Fourier_transform
# /wiki/John_Wiley_%26_Sons
# /wiki/Herman_Melville
# /wiki/Billy_Budd_(opera)
# /wiki/English_National_Opera
# /wiki/Wayback_Machine
# /wiki/Libre_Map_Project
# /wiki/Archive.org
# /wiki/Jason_Scott
# /wiki/Simon_Schwartzman#Collected_texts_of_Simon_Schwartzman
# /wiki/Brazilian_Academy_of_Sciences
# /wiki/Transnational_Institute
# /wiki/National_Academy_of_Sciences_of_Ukraine
# /wiki/Royal_Netherlands_Academy_of_Arts_and_Sciences
# /wiki/Pacific_Science_Association
# /wiki/Indonesia
# /wiki/Doi_(identifier)
# /wiki/Graph_Query_Language
# /wiki/ISO_732
# /wiki/ISO_3166-2
# /wiki/American_Samoa
# /wiki/A%CA%BBoloau
# /wiki/Demographics_of_American_Samoa
# /wiki/Public_Radio_International
# /wiki/Mutual_Lifestyle_Radio
# /wiki/WCMU-FM
# /wiki/WUPS
# /wiki/WTWS
# /wiki/WATZ-FM
# /wiki/WKFR-FM
# /wiki/KISX
# /wiki/KBJS
# /wiki/KPIT_(FM)
# /wiki/KETE
# /wiki/KKGT
# /wiki/KVNE
# /wiki/KBJS
# /wiki/WXK36
# /wiki/National_Weather_Service_Fort_Worth,_Texas
# /wiki/Stephens_County,_Texas
# /wiki/1948_United_States_presidential_election_in_Texas
# /wiki/1998_Texas_gubernatorial_election
# /wiki/2012_Corpus_Christi_mayoral_election
# /wiki/2019_San_Antonio_mayoral_election
# /wiki/2007_Houston_elections
# /wiki/Dallas%E2%80%93Fort_Worth_metroplex
# /wiki/Get_(TV_network)
# /wiki/Indianapolis
# /wiki/Miami_Nation_of_Oklahoma
# /wiki/Miami_Nation_of_Indiana
# /wiki/Bureau_of_Indian_Affairs
# /wiki/Bureau_of_Safety_and_Environmental_Enforcement
# /wiki/Deepwater_Horizon_oil_spill
# /wiki/Al_Jazeera_English
# /wiki/SIC_Internacional
# /wiki/Media_Capital
# /wiki/Stingray_Group
# /wiki/Stingray_Music_(Europe)
# /wiki/Sky_UK
# /wiki/Sky_Group
# /wiki/Digital_media
# /wiki/World_Wide_Web
# /wiki/John_Bardeen
# /wiki/Doi_(identifier)
# /wiki/ISO_15686
# /wiki/International_Standard_Audiovisual_Number
# /wiki/ISO_20400
# /wiki/ISO/IEC_19770
# /wiki/ISO_3307
# /wiki/ISO_3166-2
# /wiki/Mayotte
# /wiki/Bulgarian_irredentism
# /wiki/Movements_for_the_annexation_of_Canada_to_the_United_States
# /wiki/Indian_Commissioner
# /wiki/Flora_Warren_Seymour
# /wiki/Native_Americans_in_the_United_States
# /wiki/Urban_Indian
# /wiki/Minneapolis
# /wiki/Climate_of_Minneapolis%E2%80%93Saint_Paul
# /wiki/Sunshine_duration
# /wiki/Martine_Tabeaud
# /wiki/Institut_national_de_l%E2%80%99information_g%C3%A9ographique_et_foresti%C3%A8re
# /wiki/%C3%89cole_nationale_sup%C3%A9rieure_d%27informatique_pour_l%27industrie_et_l%27entreprise
# /wiki/ESIGELEC
# /wiki/Rouen
# /wiki/Niort
# /wiki/Saint-Amand-sur-S%C3%A8vre
# /wiki/Coulonges-Thouarsais
# /wiki/Sainte-Eanne
# /wiki/Faye-sur-Ardin
# /wiki/Saint-Paul-en-G%C3%A2tine
# /wiki/Fran%C3%A7ois,_Deux-S%C3%A8vres
# /wiki/Vasles
# /wiki/Granzay-Gript
# /wiki/Loubign%C3%A9
# /wiki/Mazi%C3%A8res-en-G%C3%A2tine
# /wiki/Saint-Cyr-la-Lande
# /wiki/Coulon,_Deux-S%C3%A8vres
# /wiki/Lavardin,_Loir-et-Cher
# /wiki/Dhuizon
# /wiki/Soug%C3%A9,_Loir-et-Cher
# /wiki/Authon,_Loir-et-Cher
# /wiki/Val%C3%A9ry_Giscard_d%27Estaing
# /wiki/Fran%C3%A7ois_d%27O
# /wiki/Jean-Andoche_Junot,_duc_d%27Abrant%C3%A8s
# /wiki/Victory_title
# /wiki/United_Kingdom_of_the_Netherlands
# /wiki/Coat_of_arms_of_the_Netherlands
# /wiki/Dutch_people
# /wiki/Brussels
# /wiki/Health_hazard
# /wiki/Countermeasure
# /wiki/Countermeasure_(law)
# /wiki/Public_international_law
# /wiki/Treaty_of_friendship
# /wiki/New_Zealand%E2%80%93Samoa_relations
# /wiki/Netherlands%E2%80%93New_Zealand_relations
# /wiki/New_Zealand%E2%80%93Tonga_relations
# /wiki/List_of_diplomatic_missions_in_Tonga
# /wiki/Soviet_Union%E2%80%93Tonga_relations
# /wiki/Soviet_Union%E2%80%93Vanuatu_relations
# /wiki/Austria%E2%80%93Soviet_Union_relations
# /wiki/International_relations_within_the_Comecon
# /wiki/Eastern_Bloc
# /wiki/ISBN_(identifier)
# /wiki/Books_in_Spain
# /wiki/History_of_printing
# /wiki/Paper
# /wiki/Litmus_paper
# /wiki/Roccella_phycopsis
# /wiki/Roccellaceae
# /wiki/Circumscription_(taxonomy)
# /wiki/Pyraloidea
# /wiki/Monotrysia
# /wiki/Whalleyana
# /wiki/Doidae
# /wiki/Simaethistoidea
# /wiki/Bedelliidae
# /wiki/Urodidae
# /wiki/Geometer_moth
# /wiki/Hedylidae
# /wiki/Rosids
# /wiki/Garryales
# /wiki/Eudicots
# /wiki/Alismatales
# /wiki/Friedrich_von_Berchtold
# /wiki/List_of_botanists_by_author_abbreviation_(A)
# /wiki/List_of_botanists_by_author_abbreviation_(W%E2%80%93Z)#Y
# /wiki/Aleksander_Zawadzki_(naturalist)
# /wiki/Internetowa_encyklopedia_PWN
# /wiki/Poland
# /wiki/Jerzy_Kukuczka
# /wiki/Lhotse
# /wiki/List_of_media_related_to_Mount_Everest
# /wiki/Ben_Fogle
# /wiki/Weekend_Today
# /wiki/Premier_League
# /wiki/Wolverhampton_Wanderers_F.C.
# /wiki/EFL_Awards
# /wiki/England
# /wiki/Sport_England
# /wiki/Scottish_Sub_Aqua_Club
# /wiki/E._Yale_Dawson
# /wiki/Sappers_Divers_Group
# /wiki/Dom_Fernando_II_e_Gl%C3%B3ria
# /wiki/Empire_of_Brazil
# /wiki/List_of_Niuean_monarchs
# /wiki/Wassoulou_Empire
# /wiki/Niagassola
# /wiki/Kangaba
# /wiki/Ouagadou
# /wiki/Kati_Cercle
# /wiki/Degnekoro
# /wiki/Toubakoro
# /wiki/Tiakadougou-Dialakoro
# /wiki/Kambila
# /wiki/Benkadi_Habaladougou
# /wiki/Nossombougou
# /wiki/Koulikoro
# /wiki/Baguin%C3%A9da-Camp
# /wiki/Communes_of_Mali
# /wiki/List_of_districts_in_Nepal
# /wiki/Siraha_District
# /wiki/Bhojpur_District,_Nepal
# /wiki/Balankha
# /wiki/Unified_Communist_Party_of_Nepal_(Maoist)
# /wiki/Rookmangud_Katawal
# /wiki/Hridayendra_Shah
# /wiki/Dynasty#Dynasts
# /wiki/Queen_regnant
# /wiki/Kang_Youwei
# /wiki/Imprisonment
# /wiki/Bermuda_Department_of_Corrections
# /wiki/Coldstream_Guards
# /wiki/Prince_William,_Duke_of_Cumberland
# /wiki/Clifton_Moor_Skirmish
# /wiki/Siege_of_Ruthven_Barracks_(1745)
# /wiki/Battle_of_Inverurie_(1745)
# /wiki/George_Munro,_1st_of_Culcairn
# /wiki/Archibald_Constable
# /wiki/Archibald_Constable_%26_Co
# /wiki/Thomas_Constable_(printer_and_publisher)
# /wiki/Constable_and_Robinson
# /wiki/Archibald_Constable
# /wiki/Scots_Magazine
# /wiki/Plug_(comics)
# /wiki/Alan_Grant_(writer)
# /wiki/Joe_Giella
# /wiki/Jerry_Ordway
# /wiki/Ron_Garney
# /wiki/Hulk
# /wiki/Fenris_Wolf_(Marvel_Comics)
# /wiki/Agatha_Harkness
# /wiki/Infinity-Man
# /wiki/T%27Chaka
# /wiki/War_Dogs_(Marvel_Cinematic_Universe)
# /wiki/Shang-Chi_(Marvel_Cinematic_Universe)
# /wiki/Werewolf_by_Night_(soundtrack)
# /wiki/Jessica_Jones_season_3
# /wiki/Rachael_Taylor
# /wiki/List_of_Grey%27s_Anatomy_characters#Attending_physicians
# /wiki/Grey%27s_Anatomy_season_19
# /wiki/Chandra_Wilson
# /wiki/Don_McBrearty
# /wiki/Television_movie
# /wiki/ABC_Movie_of_the_Week
# /wiki/Dennis_Weaver
# /wiki/War_Arrow
# /wiki/Ghost_Valley_Raiders
# /wiki/Tom_London
# /wiki/Twilight_on_the_Rio_Grande
# /wiki/Sterling_Holloway
# /wiki/Family_Affair
# /wiki/Johnny_Whitaker
# /wiki/ABC_News_(United_States)
# /wiki/Walt_Disney_Productions_v._Air_Pirates
# /wiki/Copyright_Act_of_1790
# /wiki/Georgia_v._Public.Resource.Org,_Inc.
# /wiki/Educational_Films_Corp._v._Ward
# /wiki/Juilliard_v._Greenman
# /wiki/Community_for_Creative_Non-Violence_v._Reid
# /wiki/Goldstein_v._California
# /wiki/Henderson_v._United_States_(1950)
# /wiki/Gold_Clause_Cases
# /wiki/Ex_parte_Bollman
# /wiki/Buck_v._Gallagher
# /wiki/Sakraida_v._Ag_Pro_Inc.
# /wiki/United_States_Reports
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_397
# /wiki/Walz_v._Tax_Comm%27n
# /wiki/Board_of_Education_of_Kiryas_Joel_Village_School_District_v._Grumet
# /wiki/Board_of_Airport_Commissioners_of_Los_Angeles_v._Jews_for_Jesus,_Inc.
# /wiki/United_Public_Workers_v._Mitchell
# /wiki/Freedom_of_speech_in_schools_in_the_United_States
# /wiki/Varsity_team
# /wiki/List_of_gridiron_football_rules
# /wiki/Field_goal_(football)
# /wiki/1975_CFL_season
# /wiki/Montreal_Alouettes
# /wiki/Mark_Washington_(Canadian_football)
# /wiki/Matt_Kirk
# /wiki/Ottawa_Renegades
# /wiki/Canadian_Football_League_in_the_United_States
# /wiki/Memphis_Mad_Dogs
# /wiki/Gary_Anderson_(running_back)
# /wiki/1985_USFL_season
# /wiki/Houston_Gamblers
# /wiki/Oklahoma_Outlaws
# /wiki/Greg_Landry
# /wiki/Kerry_Collins
# /wiki/Earl_Morrall
# /wiki/1952_Michigan_State_Spartans_football_team
# /wiki/1964_Arkansas_Razorbacks_football_team
# /wiki/1944_Arkansas_Razorbacks_football_team
# /wiki/Donald_W._Reynolds_Razorback_Stadium
# /wiki/FirstBank_Stadium
# /wiki/Nashville,_Tennessee
# /wiki/Tri-Cities,_Tennessee
# /wiki/Emory,_Virginia
# /wiki/Blackwell,_Virginia
# /wiki/Alvarado,_Virginia
# /wiki/South_Fork_Holston_River
# /wiki/Tennessee_State_Route_347
# /wiki/Kingsport,_Tennessee
# /wiki/Amy_Dalley
# /wiki/Reba_McEntire
# /wiki/ISSN_(identifier)
# /wiki/TIFF/EP
# /wiki/ICO_(file_format)
# /wiki/Windows_XP
# /wiki/Hibernate_(OS_feature)
# /wiki/Computer_forensics
# /wiki/Forensic_Toolkit
# /wiki/Software
# /wiki/Non-disclosure_agreement
# /wiki/California
# /wiki/Jeju_Province
# /wiki/World_War_II
# /wiki/Nagasaki
# /wiki/Ojika,_Nagasaki
# /wiki/Blue_and_white_pottery
# /wiki/Basra
# /wiki/Ilkhanate
# /wiki/Jahan_Tem%C3%BCr
# /wiki/Jalayirids
# /wiki/Iranian_folklore
# /wiki/ISBN_(identifier)
# /wiki/Graphical_Kernel_System
# /wiki/Corel_Ventura
# /wiki/Adobe_InDesign
# /wiki/MacOS
# /wiki/Computerworld
# /wiki/BPA_Worldwide
# /wiki/Newspaper
# /wiki/Star_(magazine)
# /wiki/Tabloid_(newspaper_format)
# /wiki/Populism
# /wiki/ISSN_(identifier)
# /wiki/Mixed_raster_content
# /wiki/ISO_6346
# /wiki/ISO/IEC_27001
# /wiki/ISO_11784_and_ISO_11785
# /wiki/ISO_31-13
# /wiki/126_film
# /wiki/Linux_Standard_Base
# /wiki/ISO/IEC_8859-2
# /wiki/SQUOZE#Identifier_name_character_encoding
# /wiki/Base_conversion
# /wiki/Babylonian_numerals
# /wiki/Angle
# /wiki/Hatch_mark#Congruency_notation
# /wiki/Integer
# /wiki/Additive_inverse
# /wiki/Vector_space
# /wiki/Orientation_(geometry)
# /wiki/Rotation_formalisms_in_three_dimensions
# /wiki/Vector_space
# /wiki/Erwin_Kreyszig
# /wiki/Textbook
# /wiki/List_of_book-burning_incidents
# /wiki/Theodosius_I
# /wiki/Arcadius
# /wiki/Andronikos_I_Komnenos
# /wiki/Romanos_I_Lekapenos
# /wiki/Thrace
# /wiki/Alexandroupoli
# /wiki/Soufli
# /wiki/Evros_(regional_unit)
# /wiki/Marinos_Ouzounidis
# /wiki/Edmund_Crawford
# /wiki/Peter_Shreeves
# /wiki/Lewis_Dark
# /wiki/Caretaker_manager
# /wiki/2002%E2%80%9303_in_English_football
# /wiki/1982_FA_Cup_Final
# /wiki/1981%E2%80%9382_Football_League_Third_Division
# /wiki/Blackburn_Rovers_F.C.
# /wiki/England
# /wiki/The_Royal_Society_of_London_for_Improving_Natural_Knowledge
# /wiki/Gresham_College
# /wiki/Howard_Davies_(economist)
# /wiki/Rishi_Sunak
# /wiki/UK_Rapid_Test_Consortium
# /wiki/Dominic_Cummings_scandal
# /wiki/Joint_Committee_on_Vaccination_and_Immunisation
# /wiki/COVID-19_vaccination_programme_in_the_United_Kingdom
# /wiki/Impact_of_the_COVID-19_pandemic_on_Philippine_sports
# /wiki/COVID-19_pandemic_in_New_Mexico
# /wiki/COVID-19_pandemic_in_Wisconsin
# /wiki/White_House_Coronavirus_Task_Force
# /wiki/2021_Idar-Oberstein_shooting
# /wiki/Cultural_racism
# /wiki/Modernization
# /wiki/Albigensian_Crusade#Legacy
# /wiki/Eucharist_in_the_Catholic_Church
# /wiki/Canonical_faculties_(Catholic_canon_law)
# /wiki/List_of_canonically_crowned_images
# /wiki/Vatican_Secret_Archives
# /wiki/Apostolic_nunciature
# /wiki/Ecclesiastical_Province_of_Rome
# /wiki/Roman_Catholic_Diocese_of_Sessa_Aurunca
# /wiki/Order_of_Saint_Benedict
# /wiki/Rite_of_Braga
# /wiki/Patriarch_of_the_West
# /wiki/Cyprian
# /wiki/Folk_Catholicism
# /wiki/Peasant
# /wiki/Magnate
# /wiki/Income_distribution
# /wiki/Family_income
# /wiki/Sweden
# /wiki/Lutefisk
# /wiki/Surstr%C3%B6mming
# /wiki/Baltic_herring
# /wiki/Chosa_herring
# /wiki/Goldband_fusilier
# /wiki/William_N._Eschmeyer
# /wiki/Gale_(identifier)
# /wiki/Encyclopedia_of_Associations
# /wiki/Voluntary_associations
# /wiki/Nicholas_Sarwark
# /wiki/Spontaneous_order
# /wiki/Neo-classical_liberalism
# /wiki/Religious_liberalism
# /wiki/Hu_Shih
# /wiki/Doi_(identifier)
# /wiki/ISO_31-10
# /wiki/Meta-Object_Facility
# /wiki/Guidelines_for_the_Definition_of_Managed_Objects
# /wiki/ISO_31-7
# /wiki/ISO/IEC_8859-3
# /wiki/Prolog
# /wiki/ISO/IEC_5218
# /wiki/AES3
# /wiki/PHIGS
# /wiki/Linux_Standard_Base
# /wiki/C_standard_library
# /wiki/Namespace_(programming)
# /wiki/Programming_language
# /wiki/Hardware_acceleration
# /wiki/Adreno
# /wiki/List_of_Qualcomm_Snapdragon_devices#Snapdragon_617
# /wiki/List_of_Qualcomm_Snapdragon_processors#Snapdragon_7_(2022–2024)
# /wiki/ARM_Cortex-A55
# /wiki/Exynos_(system_on_chip)
# /wiki/List_of_MediaTek_processors#Dimensity_7000_Series
# /wiki/GPS
# /wiki/Northrop_T-38_Talon
# /wiki/Consolidated_PT-11
# /wiki/Consolidated_PT-3
# /wiki/Power-to-weight_ratio
# /wiki/Electric_machine
# /wiki/Moritz_von_Jacobi
# /wiki/Commutator_(electric)
# /wiki/Moritz_von_Jacobi
# /wiki/Dahlander_pole_changing_motor
# /wiki/Direct_torque_control
# /wiki/Joseph_Saxton
# /wiki/AC-to-AC_converter
# /wiki/Inchworm_motor
# /wiki/DC_motor
# /wiki/Frank_J._Sprague
# /wiki/Robert_C._Sprague
# /wiki/National_Academy_of_Engineering
# /wiki/Eric_A._Walker_(engineer)
# /wiki/National_Academy_of_Engineering
# /wiki/California_Institute_of_Technology
# /wiki/UCSB_College_of_Engineering
# /wiki/UC_Santa_Barbara_Gauchos_women%27s_basketball
# /wiki/California_Polytechnic_State_University,_San_Luis_Obispo
# /wiki/NCAA_Division_I
# /wiki/Utah_Tech_Trailblazers_football
# /wiki/Idaho_State_Bengals_football
# /wiki/2014_Idaho_State_Bengals_football_team
# /wiki/Simon_Fraser_Clan_football
# /wiki/CJSF-FM
# /wiki/Burnaby
# /wiki/Rossland,_British_Columbia
# /wiki/British_Columbia_Highway_22
# /wiki/Canada%E2%80%93United_States_border
# /wiki/Alberta
# /wiki/Government_of_Canada
# /wiki/Constitution_Act,_1867
# /wiki/Patriation#The_Kitchen_Accord
# /wiki/Unsuccessful_attempts_to_amend_the_Canadian_Constitution
# /wiki/Victoria_Charter
# /wiki/Sovereign_Council_of_New_France
# /wiki/Section_91(2)_of_the_Constitution_Act,_1867
# /wiki/British_North_America_Acts
# /wiki/6_%26_7_Geo._6
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_1805
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_1931
# /wiki/List_of_acts_of_the_National_Assembly_for_Wales_from_2012
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_1941
# /wiki/List_of_acts_of_the_Parliament_of_Scotland,_1540%E2%80%931558
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain_from_1753
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain_from_1783
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_1987
# /wiki/List_of_acts_of_the_Parliament_of_England_from_1678
# /wiki/Google_Books
# /wiki/Web_crawler
# /wiki/S2CID_(identifier)
# /wiki/Scientometrics
# /wiki/Citation_analysis
# /wiki/Citation_indices
# /wiki/PMID_(identifier)
# /wiki/Health_education
# /wiki/Education_in_Cameroon
# /wiki/Education_in_Mali
# /wiki/Demographics_of_Mali
# /wiki/Demographics_of_Uganda
# /wiki/Adhola_people
# /wiki/Konjo_people
# /wiki/Nyoro_people
# /wiki/Hema_people
# /wiki/Mobutu_Sese_Seko
# /wiki/Cold_War
# /wiki/Vietnam_War
# /wiki/John_Costello_(historian)
# /wiki/1969_Libyan_revolution
# /wiki/White_nationalism
# /wiki/American_Nazi_Party
# /wiki/National_Socialist_Party_of_America
# /wiki/Illinois
# /wiki/Asian_American
# /wiki/PMID_(identifier)
# /wiki/Health_information_on_the_Internet
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_27002
# /wiki/Essential_Video_Coding
# /wiki/VP3
# /wiki/G.719
# /wiki/Vorbis
# /wiki/FreeArc
# /wiki/Data_compression#Audio
# /wiki/The_Atlantic
# /wiki/Plagiarism
# /wiki/Parody
# /wiki/Cut-up_technique
# /wiki/Assemblage_(art)
# /wiki/Anti-art
# /wiki/Guy_Debord
# /wiki/G%C3%A9rard_Lebovici
# /wiki/Cognac
# /wiki/Tuhak
# /wiki/Sinigapuna
# /wiki/Palapa_(condiment)
# /wiki/Sahawiq
# /wiki/Moroccan_carrot_salad
# /wiki/Bean_salad
# /wiki/Mizeria
# /wiki/Green_papaya_salad
# /wiki/Monosodium_glutamate
# /wiki/Chronic_disease
# /wiki/Hypertension
# /wiki/Criticism_of_fast_food
# /wiki/Genetically_modified_food
# /wiki/Genetically_modified_organism
# /wiki/Genetic_engineering
# /wiki/Offshore_engineering
# /wiki/Soil
# /wiki/Aerobic_organism
# /wiki/N-Acetylmuramic_acid
# /wiki/CompTox_Chemicals_Dashboard
# /wiki/S2CID_(identifier)
# /wiki/Imprint_(trade_name)
# /wiki/Scientific_journal
# /wiki/Chapter_(books)
# /wiki/Bestseller
# /wiki/List_of_best-selling_singles
# /wiki/One_Direction
# /wiki/Arashi
# /wiki/Love_Rainbow
# /wiki/Billboard_Japan
# /wiki/Oricon_Combined_Singles_Chart
# /wiki/Gigaku
# /wiki/ISBN_(identifier)
# /wiki/Pop-up_book
# /wiki/Print_culture
# /wiki/Thomas_Paine
# /wiki/Pension
# /wiki/Sleeping_while_on_duty
# /wiki/Schedule_(workplace)
# /wiki/Career_break
# /wiki/Practice-based_professional_learning
# /wiki/Practice_(learning_method)
# /wiki/ISBN_(identifier)
# /wiki/Book_tour
# /wiki/Politics_and_Prose
# /wiki/Washington_Monument
# /wiki/Adams_Memorial
# /wiki/Jefferson_Pier
# /wiki/National_Liberty_Memorial
# /wiki/Marine_Corps_War_Memorial
# /wiki/United_States_Marine_Corps_Recruit_Training#Week_10-The_Crucible
# /wiki/Service_number_(United_States_Armed_Forces)
# /wiki/United_States_Air_Force_officer_rank_insignia
# /wiki/RAF_officer_ranks
# /wiki/Squadron_leader
# /wiki/Brigadier_(United_Kingdom)
# /wiki/List_of_Royal_Navy_vice_admirals
# /wiki/Major_(United_Kingdom)
# /wiki/Lieutenant_(British_Army_and_Royal_Marines)
# /wiki/Acting_pilot_officer
# /wiki/NATO
# /wiki/Housing_and_Home_Finance_Agency
# /wiki/United_States_Department_of_Housing_and_Urban_Development
# /wiki/Medicare_(United_States)
# /wiki/United_States_Senate_Committee_on_Appropriations
# /wiki/Shelley_Moore_Capito
# /wiki/Donald_Trump
# /wiki/Prosecution_of_Donald_Trump_in_New_York
# /wiki/Presidential_immunity
# /wiki/Office_of_Legal_Counsel
# /wiki/Oxford_University_Press
# /wiki/Oxford_University_Student_Union
# /wiki/Universities_of_Oxford_and_Cambridge_Act_1859
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_1806
# /wiki/Statute_Law_Revision_Act_1872
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_2016
# /wiki/List_of_acts_of_the_Parliament_of_England_from_1488
# /wiki/6_Hen._8
# /wiki/List_of_acts_of_the_Parliament_of_England_from_1571
# /wiki/List_of_acts_of_the_Parliament_of_England_from_1566
# /wiki/List_of_ordinances_and_acts_of_the_Parliament_of_England,_1642%E2%80%931660
# /wiki/Historic_counties_of_England
# /wiki/Huntingdonshire
# /wiki/Essex
# /wiki/2024_UK_general_election
# /wiki/Candidates_in_the_2024_United_Kingdom_general_election#Parties
# ...
# /wiki/Due_process
# /wiki/Ministerial_act
# /wiki/Judgment
# /wiki/Upek%E1%B9%A3%C4%81
# /wiki/Buddhism_and_Gnosticism
# /wiki/Cerinthus
# /wiki/Luminary_(Gnosticism)
# /wiki/Shekhinah
# /wiki/Adathan_and_Yadathan
# /wiki/Gubran
# /wiki/Mandaean_Americans
# /wiki/Rafid_al-Sabti
# /wiki/Laufa
# /wiki/Nbat
# /wiki/Destroying_angel_(Bible)
# /wiki/Muriel_(angel)
# /wiki/N%C4%81zi%27%C4%81t_and_N%C4%81shi%E1%B9%AD%C4%81t
# /wiki/Yurba
# /wiki/Tarmida
# /wiki/Margna
# /wiki/Nuna_(month)
# /wiki/Sea_of_Suf
# /wiki/Adam
# /wiki/Eve_(Davidson)
# /wiki/The_Creation_of_Adam
# /wiki/Day_(Michelangelo)
# /wiki/Night_(Michelangelo)
# /wiki/Fountain_of_Neptune,_Florence
# /wiki/Florence
# /wiki/Chianti_(region)
# /wiki/Impruneta
# /wiki/Etruscan_civilization
# /wiki/Rusellae
# /wiki/Etruria
# /wiki/Lars_Porsena
# /wiki/Ceri
# /wiki/UTC%2B2
# /wiki/Bordeaux
# /wiki/Moulon,_Gironde
# /wiki/Saint-L%C3%A9on,_Gironde
# /wiki/Fargues-Saint-Hilaire
# /wiki/Saint-Pierre-d%27Aurillac
# /wiki/Avensan
# /wiki/Camarsac
# /wiki/Saint-Martin-du-Puy,_Gironde
# /wiki/Saint-Trojan
# /wiki/Caplong
# /wiki/Saint-Gen%C3%A8s-de-Blaye
# /wiki/Saint-Michel-de-Lapujade
# /wiki/Pugnac
# /wiki/Izon,_Gironde
# /wiki/Institut_national_de_la_statistique_et_des_%C3%A9tudes_%C3%A9conomiques
# /wiki/SIREN_code
# /wiki/Voluntary_association
# /wiki/Stephen_Pearl_Andrews
# /wiki/Egoist_anarchism
# /wiki/Biennio_Rosso
# /wiki/Italian_Socialist_Party
# /wiki/Italian_fascist
# /wiki/L%C4%83ncieri
# /wiki/Abdolhossein_Teymourtash
# /wiki/Ali_Akbar_Davar
# /wiki/ISBN_(identifier)
# /wiki/Printing
# /wiki/Bookselling
# /wiki/List_of_independent_bookstores
# /wiki/List_of_largest_oil_and_gas_companies_by_revenue
# /wiki/Brunei_Energy_Services_and_Trading
# /wiki/Petroleum_industry
# /wiki/Petroleum_engineering
# /wiki/International_Energy_Agency
# /wiki/2010s_oil_glut
# /wiki/Saudi_Arabia
# /wiki/Somaliland
# /wiki/Habr_Yunis_Sultanate
# /wiki/Reer_Caynaashe
# /wiki/William_Archibald_Macfadyen
# /wiki/Cambridge_University
# /wiki/The_Theory_of_Everything_(2014_film)
# /wiki/Anthony_McCarten
# /wiki/A_Beautiful_Noise_(musical)
# /wiki/Yesterday%27s_Songs
# /wiki/Record_World
# /wiki/Harry_Chapin
# /wiki/National_Board_of_Review_of_Motion_Pictures
# /wiki/National_Board_of_Review_Awards_1958
# /wiki/National_Board_of_Review_Awards_1990
# /wiki/National_Board_of_Review_Awards_2017
# /wiki/National_Board_of_Review_Awards_1932
# /wiki/National_Board_of_Review_Awards_1972
# /wiki/National_Board_of_Review_Awards_1948
# /wiki/National_Board_of_Review_Awards_1986
# /wiki/National_Board_of_Review_Awards_1989
# /wiki/NBR_Freedom_of_Expression
# /wiki/National_Board_of_Review_Awards_1978
# /wiki/National_Board_of_Review_Awards_1967
# /wiki/National_Board_of_Review_Awards_1932
# /wiki/M%C3%A4dchen_in_Uniform_(1931_film)
# /wiki/IMDb_(identifier)
# /wiki/The_Boston_Globe
# /wiki/The_Harvard_Crimson
# /wiki/Boston_Medical_Library
# /wiki/Harvard_Crimson_women%27s_volleyball
# /wiki/Widener_Library
# /wiki/Srikant_Datar
# /wiki/Innovation
# /wiki/Potash#Production
# /wiki/Potassium_hydroxide
# /wiki/Potassium_cyanate
# /wiki/Potassium_hexafluoroarsenate
# /wiki/Ammonium_hexafluoroniobate
# /wiki/Microcosmic_salt
# /wiki/Ammonium_dihydrogen_arsenate
# /wiki/Ammonium_bisulfate
# /wiki/Dunnite
# /wiki/Ammonium_hexachlororhodate(III)
# /wiki/International_Chemical_Identifier
# /wiki/SMILES
# /wiki/COSILAB
# /wiki/Chemistry
# /wiki/Computer_program
# /wiki/Objective-C
# /wiki/Xcode
# /wiki/PhpStorm
# /wiki/Rust_(programming_language)
# /wiki/Monitor_(synchronization)
# /wiki/Memento_pattern
# /wiki/Prototype_pattern
# /wiki/Jim_Coplien
# /wiki/Vrije_Universiteit_Brussel
# /wiki/Wouter_Beke
# /wiki/Christen-Democratisch_en_Vlaams
# /wiki/Familialism
# /wiki/Conservatism#Finland
# /wiki/Naomi_Seibt
# /wiki/YouTuber
# /wiki/Blocking_of_YouTube_videos_in_Germany
# /wiki/List_of_exports_of_Germany
# /wiki/Machine
# /wiki/Antikythera_mechanism
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Isofix
# /wiki/ISO/IEC_8859-6
# /wiki/Soft_hyphen
# /wiki/Nandinagari
# /wiki/Thomas_Natural_Shorthand
# /wiki/Louis_Braille
# /wiki/Vibratese
# /wiki/Windows_Polytonic_Greek
# /wiki/%E1%BC%98
# /wiki/%E1%BE%AA
# /wiki/%E1%BC%B8
# /wiki/Nu_(letter)
# /wiki/Translesion_synthesis
# /wiki/PMID_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Open-notebook_science
# /wiki/Open_source
# /wiki/Comparison_of_source-code-hosting_facilities
# /wiki/Team_Foundation_Version_Control
# /wiki/Connectix
# /wiki/Amy_Hood
# /wiki/Skype_Technologies
# /wiki/IDT_Corp.
# /wiki/T-Mobile_(USA)
# /wiki/Metro_by_T-Mobile#Merger_with_T-Mobile
# /wiki/Upoc_Networks
# /wiki/Wireless_Application_Protocol
# /wiki/Synchronous_Data_Link_Control
# /wiki/Point-to-multipoint_communication_(telecommunications)
# /wiki/Antonio_Meucci
# /wiki/Wayback_Machine
# /wiki/Internet_Archive
# /wiki/Barnes_%26_Noble_Nook
# /wiki/Kobo_Arc
# /wiki/Samsung_Galaxy_Tab_3_10.1
# /wiki/Pakistan_Aeronautical_Complex
# /wiki/Pakistan
# /wiki/ISBN_(identifier)
# /wiki/ISO_1
# /wiki/ISO_45001
# /wiki/Antimagnetic_watch
# /wiki/ISO/IEC_38500
# /wiki/Z_notation
# /wiki/Essential_Video_Coding
# /wiki/AMV_video_format
# /wiki/DivX#DivX_Media_Format_(DMF)
# /wiki/MPEG_Surround
# /wiki/MPEG-21
# /wiki/ISO_4165
# /wiki/Business_Process_Model_and_Notation
# /wiki/Standard_Generalized_Markup_Language
# /wiki/Automata_theory
# /wiki/Compiler_construction
# /wiki/ISBN_(identifier)
# /wiki/Dust_jacket
# /wiki/Book_illustration
# /wiki/Limited-edition_book
# /wiki/Souvenir
# /wiki/Helsinki
# /wiki/World_Figure_Skating_Championships
# /wiki/Lyon
# /wiki/Strasbourg
# /wiki/Place_Broglie
# /wiki/Geographic_coordinate_system
# /wiki/60th_meridian_west
# /wiki/15th_parallel_north
# /wiki/40th_meridian_east
# /wiki/Tropic_of_Capricorn
# /wiki/Argentina
# /wiki/Argentine_general_election,_2003
# /wiki/Felipe_Sol%C3%A1
# /wiki/Miguel_Giubergia
# /wiki/Chaco_Province
# /wiki/Campo_Largo,_Chaco
# /wiki/Departments_of_Argentina
# /wiki/Bella_Vista,_Tucum%C3%A1n
# /wiki/Mayor
# /wiki/Argentina
# /wiki/FIH_Player_of_the_Year_Awards
# /wiki/Spain
# /wiki/Marcha_Real
# /wiki/Timeline_of_Hispania
# /wiki/Decimus_Junius_Brutus_Callaicus
# /wiki/Circus_Flaminius
# /wiki/Sulla
# /wiki/Troy
# /wiki/Amphictyonic_League
# /wiki/Ostracism
# /wiki/Anti-authoritarianism
# /wiki/Anarchism_in_French_Guiana
# /wiki/Anarchism_in_Colombia
# /wiki/Anarcho-syndicalists
# /wiki/Perspectives_on_capitalism_by_school_of_thought
# /wiki/Johann_Heinrich_von_Th%C3%BCnen
# /wiki/Wangerland
# /wiki/Wilhelmshaven
# /wiki/Uelzen_(district)
# /wiki/Germany
# /wiki/ISBN_(identifier)
# /wiki/ISO_31-11
# /wiki/Unified_Modeling_Language
# /wiki/Software_testing
# /wiki/Software_quality_assurance
# /wiki/IEEE_802
# /wiki/IEEE_802.15
# /wiki/802.3ac
# /wiki/IEEE_802.11g-2003
# /wiki/Wi-Fi_7
# /wiki/Apple_Inc
# /wiki/Multinational_corporation
# /wiki/Government_procurement
# /wiki/President_of_Peru
# /wiki/ISBN_(identifier)
# /wiki/ISO_19439
# /wiki/ISO_31-12
# /wiki/ISO_999
# /wiki/CHILL
# /wiki/ISO_1
# /wiki/ISO_6438
# /wiki/EBCDIC
# /wiki/Galaksija_(computer)#Character_ROM
# /wiki/Sam_Coup%C3%A9
# /wiki/RGB_color_model
# /wiki/Color_vision
# /wiki/Human_eye
# /wiki/Binocular_vision
# /wiki/Binocular_rivalry
# /wiki/Multiscopy
# /wiki/Lenticular_printing
# /wiki/The_Rolling_Stones
# /wiki/Indio,_California
# /wiki/Guthy-Renker
# /wiki/ISBN_(identifier)
# /wiki/Graphical_Kernel_System
# /wiki/IEC_60269
# /wiki/IEC_60027
# /wiki/Binary_prefix
# /wiki/JEDEC
# /wiki/Mullard%E2%80%93Philips_tube_designation
# /wiki/Rectifier
# /wiki/Crystal_detector
# /wiki/Modulation
# /wiki/Electrical_telegraph#History
# /wiki/Gutta-percha
# /wiki/Elastomer
# /wiki/Intermolecular_force
# /wiki/Enzyme
# /wiki/Catalyst
# /wiki/Dye-sensitized_solar_cell
# /wiki/Thin_film_solar_cell
# /wiki/Cadmium_telluride
# /wiki/First_Solar
# /wiki/Solar_cell
# /wiki/Cadmium_telluride_photovoltaics
# /wiki/Printed_solar_panel
# /wiki/Solyndra
# /wiki/Solar_panel
# /wiki/Loft
# /wiki/Secret_passage
# /wiki/Balcony
# /wiki/Saint_Petersburg
# /wiki/Ancient_Rus%27
# /wiki/Byzantine_Rite
# /wiki/Sub_tuum_praesidium
# /wiki/Vespers
# /wiki/Liturgy_of_the_Presanctified_Gifts
# /wiki/Myrrh#In_contemporary_Christianity
# /wiki/Kauri_gum
# /wiki/Gamboge
# /wiki/Gutta-percha
# /wiki/Boston,_Massachusetts
# /wiki/Statue_of_William_Lloyd_Garrison
# /wiki/Equestrian_statue_of_Joseph_Hooker
# /wiki/T._A._Chapman_Memorial
# /wiki/Spirit_of_commerce
# /wiki/Leif,_the_Discoverer_(Whitney)
# /wiki/Statue_of_Jacques_Marquette_(Milwaukee,_Wisconsin)
# /wiki/Marquette_University_Law_School#Facilities
# /wiki/University_of_Iowa_College_of_Law
# /wiki/University_of_Kansas_School_of_Law
# /wiki/Allen_Fieldhouse
# /wiki/1988_NCAA_Division_I_men%27s_basketball_tournament
# /wiki/1988_NCAA_Division_I_Men%27s_Basketball_Championship_Game
# /wiki/1987%E2%80%9388_NCAA_Division_I_men%27s_basketball_season
# /wiki/1988_SEC_men%27s_basketball_tournament
# /wiki/1943_SEC_men%27s_basketball_tournament
# /wiki/1986_SEC_men%27s_basketball_tournament
# /wiki/1978_NCAA_Division_I_basketball_tournament
# /wiki/Philadelphia
# /wiki/Old_City,_Philadelphia
# /wiki/National_Register_of_Historic_Places_listings_in_Butler_County,_Pennsylvania
# /wiki/Wahlville,_Pennsylvania
# /wiki/Connoquenessing,_Pennsylvania
# /wiki/North_Washington,_Pennsylvania
# /wiki/Fernway,_Pennsylvania
# /wiki/Cherry_Valley,_Pennsylvania
# /wiki/Shanor-Northvue,_Pennsylvania
# /wiki/UTC-4
# /wiki/Tortola
# /wiki/Slave
# /wiki/Luanda
# /wiki/Roller_hockey_(quad)
# /wiki/Latin_Cup_(roller_hockey)
# /wiki/Portugal
# /wiki/Mediterranean_climate
# /wiki/Effects_of_global_warming
# /wiki/Polar_amplification
# /wiki/2021_in_climate_change
# /wiki/Federal_Constitutional_Court
# /wiki/Stephan_Harbarth
# /wiki/Peter_Aumer
# /wiki/List_of_members_of_the_17th_Bundestag
# /wiki/Leo_Dautzenberg
# /wiki/Wolfgang_Thierse
# /wiki/Hans-Peter_Uhl
# /wiki/Joschka_Fischer
# /wiki/Claudia_Nolte
# /wiki/Friedrich_Zimmermann
# /wiki/Johann_Cramer_(politician)
# /wiki/Karl_Ravens
# /wiki/Paul_Mikat
# /wiki/Hans_A._Engelhard
# /wiki/Hans_Koschnick
# /wiki/Hans_A._Engelhard
# /wiki/Nils_Diederich
# /wiki/Bundestag
# /wiki/Legislature_of_Guam
# /wiki/Politics_of_Guam
# /wiki/Elections_in_Guam
# /wiki/Elections_in_Tuvalu
# /wiki/Pelenike_Isaia
# /wiki/2015_Tuvaluan_general_election
# /wiki/1974_Ellice_Islands_self-determination_referendum
# /wiki/Simon_Kofe
# /wiki/Incumbent
# /wiki/List_of_current_heads_of_state_and_government
# /wiki/Governor-General_of_Saint_Lucia
# /wiki/Charles_III
# /wiki/Camilla_Parker_Bowles
# /wiki/Royal_National_Hospital_for_Rheumatic_Diseases
# /wiki/Somerset_Archives_and_Local_Studies
# /wiki/Somerset
# /wiki/Downside_School
# /wiki/Taunton_School
# /wiki/Robert_Malpas
# /wiki/Managing_director
# /wiki/Vice_president
# /wiki/Trade_union
# /wiki/Insurance#Casualty_insurance
# /wiki/Laser_construction
# /wiki/Neon
# /wiki/Francium
# /wiki/Radioactive_decay#Types_of_decay
# /wiki/Isomeric_transition
# /wiki/Technetium#Industrial_and_chemical
# /wiki/Helium
# /wiki/Texas
# /wiki/Division_I-FBS
# /wiki/Furman_University
# /wiki/Simmons_University
# /wiki/Sondra_Perl
# /wiki/Millburn_High_School
# /wiki/Bard_High_School_Early_College_Newark
# /wiki/National_Center_for_Education_Statistics
# /wiki/National_Center_for_Health_Statistics
# /wiki/Bureau_of_Economic_Analysis
# /wiki/United_States
# /wiki/United_States_Supreme_Court_Building
# /wiki/Theodore_Roosevelt
# /wiki/Charles_E._Merrill
# /wiki/Eleanor_Roosevelt
# /wiki/Carlotta_Walls_LaNier
# /wiki/Kenneth_B._Clark
# /wiki/ISBN_(identifier)
# /wiki/ISO_15398
# /wiki/Graphical_Kernel_System
# /wiki/API
# /wiki/ANSI-SPARC_Architecture
# /wiki/Three_schema_approach
# /wiki/Conceptual_model
# /wiki/S2CID_(identifier)
# /wiki/Computer_science
# /wiki/Computer_security
# /wiki/Fault_tolerance
# /wiki/Lockstep_(computing)
# /wiki/In_situ
# /wiki/Doi_(identifier)
# /wiki/ISO_6344
# /wiki/DICOM
# /wiki/110_film
# /wiki/Essential_Video_Coding
# /wiki/MT9
# /wiki/G.722
# /wiki/Society_of_Motion_Picture_and_Television_Engineers
# /wiki/Ralph_Morgan
# /wiki/Harry_Warner
# /wiki/William_J._Tuttle
# /wiki/20th_Century_Fox
# /wiki/Disney_Comics_(publishing)
# /wiki/Pendulum_Press
# /wiki/Northwest_Press
# /wiki/ComicsOne
# /wiki/Kazan_(manga)
# /wiki/Usagi-chan_de_Cue!!
# /wiki/Young_King_OURs
# /wiki/Anime_News_Network
# /wiki/Glovision
# /wiki/Acquire_(company)
# /wiki/ASCII_Media_Works
# /wiki/Internet
# /wiki/Social_media
# /wiki/PMID_(identifier)
# /wiki/PubMed_Central
# /wiki/Health_informatics
# /wiki/EHealth
# /wiki/Telenursing
# /wiki/ISSN_(identifier)
# /wiki/ISO/IEC_8859-12
# /wiki/Em_(Cyrillic)
# /wiki/Kje
# /wiki/A_with_ring_above_(Cyrillic)
# /wiki/Rha_(Cyrillic)
# /wiki/Broad_On
# /wiki/Je_with_belt
# /wiki/O_with_open_top
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-52521cd412f6> in <cell line: 14>()
#      15     newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      16     print(newArticle)
# ---> 17     links = getLinks(newArticle)
#
# <ipython-input-4-52521cd412f6> in getLinks(articleUrl)
#       7 random.seed(datetime.datetime.now().strftime('%s'))
#       8 def getLinks(articleUrl):
# ----> 9     html = urlopen(f'http://en.wikipedia.org{articleUrl}')
#      10     bs = BeautifulSoup(html, 'html.parser')
#      11     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:Search
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Special:WhatLinksHere/User_talk:34.150.152.238
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-c5465d2f120f> in <cell line: 17>()
#      15                 pages.add(newPage)
#      16                 getLinks(newPage)
# ---> 17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#       5 pages = set()
#       6 def getLinks(pageUrl):
# ----> 7     html = urlopen(f'http://en.wikipedia.org{pageUrl}')
#       8     bs = BeautifulSoup(html, 'html.parser')
#       9     for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        #mw-parser-output
        bodyContent = bs.find('div', {'id':'bodyContent'}).find_all('p')
        if len(bodyContent):
            print(bodyContent[0])
        print(bs.find(id='ca-edit').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')

    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('/wiki/General-purpose_programming_language')
# Out:
# General-purpose programming language
# <p>In <a class="mw-redirect" href="/wiki/Computer_software" title="Computer software">computer software</a>, a <b>general-purpose programming language</b> (<b>GPL</b>) is a <a href="/wiki/Programming_language" title="Programming language">programming language</a> for building <a href="/wiki/Software" title="Software">software</a> in a wide variety of application <a href="/wiki/Domain_(software_engineering)" title="Domain (software engineering)">domains</a>. Conversely, a <a href="/wiki/Domain-specific_language" title="Domain-specific language">domain-specific programming language</a> (DSL) is used within a specific area. For example, <a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python</a> is a GPL, while <a href="/wiki/SQL" title="SQL">SQL</a> is a DSL for <a href="/wiki/Query_language" title="Query language">querying relational databases</a>.
# </p>
# /w/index.php?title=General-purpose_programming_language&action=edit
# --------------------
# /wiki/Main_Page
# Main Page
# <p><b><a href="/wiki/Gedling_Town_F.C." title="Gedling Town F.C.">Gedling Town Football Club</a></b> was a <a href="/wiki/Semi-professional_sports#United_Kingdom" title="Semi-professional sports">semi-professional</a> association football club based in <a href="/wiki/Stoke_Bardolph" title="Stoke Bardolph">Stoke Bardolph</a> in <a href="/wiki/Nottinghamshire" title="Nottinghamshire">Nottinghamshire</a>, England. Founded in 1985 as R &amp; R Scaffolding, the <a href="/wiki/Works_team#Association_football" title="Works team">works team</a> of a construction firm from <a href="/wiki/Netherfield,_Nottinghamshire" title="Netherfield, Nottinghamshire">Netherfield</a>, the club played its first four seasons in <a href="/wiki/Amateur_sports#Association_football" title="Amateur sports">amateur football</a>. Between 1990 and 2008, Gedling competed in three <a href="/wiki/Central_Midlands_Alliance_League" title="Central Midlands Alliance League">Central Midlands Football League</a> divisions and Division One of the <a href="/wiki/Northern_Counties_East_Football_League" title="Northern Counties East Football League">Northern Counties East Football League</a>, winning three league titles in the process. Gedling then joined the Premier Division of the <a href="/wiki/East_Midlands_Counties_Football_League" title="East Midlands Counties Football League">East Midlands Counties Football League</a> at the tenth tier of the <a href="/wiki/English_football_league_system" title="English football league system">English football pyramid</a>, in which the club remained until its dissolution in 2011 due to <a href="/wiki/Insolvency#United_Kingdom" title="Insolvency">insolvency</a>. Its home ground from the early 1990s was the Riverside Stadium behind the Ferry Boat Inn <i>(pictured)</i>. Tournament records included reaching the third qualifying round of the <a href="/wiki/FA_Cup" title="FA Cup">FA Cup</a> in 2003–04 and the fourth round of the <a href="/wiki/FA_Vase" title="FA Vase">FA Vase</a> in 2003–04, 2004–05 and 2005–06. The team were nicknamed "The Ferrymen", and their colours were primarily yellow and blue. (<b><a href="/wiki/Gedling_Town_F.C." title="Gedling Town F.C.">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Contents
# Wikipedia:Contents
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Portal:Current_events
# Portal:Current events
# <p><b>Armed conflicts and attacks</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Random
# Live at Donte's (Joe Pass album)
# <p><i><b>Live at Donte's</b></i> (or <i><b>The Joe Pass Trio Live at Donte's</b></i>) is a live album by American jazz guitarist <a href="/wiki/Joe_Pass" title="Joe Pass">Joe Pass</a> recorded in 1974 but first released in 1981 on Pablo Records as a <a href="/wiki/Double_album" title="Double album">double album</a>. After spending over ten years playing in relative obscurity, Pass released the critically acclaimed solo-guitar <i><a href="/wiki/Virtuoso_(Joe_Pass_album)" title="Virtuoso (Joe Pass album)">Virtuoso</a></i> and also played on two <a href="/wiki/Ella_Fitzgerald" title="Ella Fitzgerald">Ella Fitzgerald</a> albums.
# </p>
# /w/index.php?title=Live_at_Donte%27s_(Joe_Pass_album)&action=edit
# --------------------
# /wiki/Wikipedia:About
# Wikipedia:About
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Contents
# Help:Contents
# <p>
# <style data-mw-deduplicate="TemplateStyles:r1012508797">.mw-parser-output .helpContents-wrapper{display:flex;flex-wrap:wrap}.mw-parser-output .helpContents-header{flex:1 0 100%;padding-bottom:1em;border-bottom:1px solid #a2a9b1;text-align:center}.mw-parser-output .helpContents-section{position:relative;flex:1 0 50%;min-width:380px;box-sizing:border-box;margin:1em 0;padding-left:30px;padding-right:20px}.mw-parser-output .helpContents-section h2{font-size:21px;padding:0;margin-top:1em;margin-bottom:0.25em;line-height:1.5}.mw-parser-output .helpContents-section ul{margin-left:0;padding-left:0}.mw-parser-output .helpContents-icon{position:absolute;top:25px;left:0;line-height:1;opacity:0.7}.mw-parser-output .helpContents-additional-search{text-align:center;margin-bottom:1em}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Introduction
# Help:Introduction
# <p><style data-mw-deduplicate="TemplateStyles:r1239334454">.mw-parser-output .introtosingle__main{position:relative;box-sizing:border-box;max-width:100%;overflow:hidden;border:1px solid var(--border-color-base,#a2a9b1);margin:auto;padding-bottom:20px}.mw-parser-output .introtosingle__main p{margin-bottom:2.0em}.mw-parser-output .introtosingle__main-withbackground{background-image:url("https://upload.wikimedia.org/wikipedia/commons/d/d9/Wikipedia-logo-v2-o10.svg");background-position:center -500px;background-repeat:no-repeat;background-size:auto 150%}.mw-parser-output .introtosingle__main-title{font-size:250%;line-height:150%;background:#777;color:#FFF;text-align:center;font-weight:bold}.mw-parser-output .introtosingle__lead{background-color:#EEE;background-color:rgba(221,221,221,0.5);padding:30px 60px;margin-bottom:15px}.mw-parser-output .introtosingle__base{box-sizing:border-box;max-width:1100px;min-height:55px;margin:auto;padding:5px 20px;font-size:1.1em;background:var(--background-color-interactive,#eaecf0);border:1px solid var(--border-color-subtle,#c8ccd1);border-top:0}.mw-parser-output .introtosingle__columns{display:flex;flex-direction:row;flex-wrap:wrap-reverse;justify-content:center}.mw-parser-output .introtosingle__columns-left,.mw-parser-output .introtosingle__columns-left-noborder,.mw-parser-output .introtosingle__columns-right{display:inline-block;flex:1 1 0;align-self:flex-end;vertical-align:top;min-width:200px;max-width:300px;padding:10px}.mw-parser-output .introtosingle__columns-left{text-align:right;justify-content:right;border-right:solid 1px #ddd}.mw-parser-output .introtosingle__columns-left-noborder{text-align:right;justify-content:right}.mw-parser-output .introtosingle__columns-right{text-align:left;justify-content:left}@media screen and (min-width:1101px){.mw-parser-output .introtosingle__main{max-width:1100px}}@media screen{html.skin-theme-clientpref-night .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}html.skin-theme-clientpref-night .mw-parser-output .introtosingle__main-title{background-color:#24282c}}@media screen and (prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .introtosingle__main-title{background-color:#24282c}html.skin-theme-clientpref-os .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Community_portal
# Wikipedia:Community portal
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:RecentChanges
# Recent changes
# <p>This is a list of recent changes to Wikipedia.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:File_upload_wizard
# Wikipedia:File upload wizard
# <p>Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Search
# Search
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyContributions
# User contributions for 34.150.152.238
# <p>This IP address is currently blocked.
# The latest block log entry is provided below for reference:
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyTalk
# User talk:34.150.152.238
# <p>This user is currently blocked.
# The latest block log entry is provided below for reference:
# </p>
# /w/index.php?title=User_talk:34.150.152.238&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/User_talk:34.150.152.238
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-cd48ffad1cde> in <cell line: 28>()
#      26                 pages.add(newPage)
#      27                 getLinks(newPage)
# ---> 28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-cd48ffad1cde> in getLinks(pageUrl)
#       5 pages = set()
#       6 def getLinks(pageUrl):
# ----> 7     html = urlopen(f'http://en.wikipedia.org{pageUrl}')
#       8     bs = BeautifulSoup(html, 'html.parser')
#       9     try:
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc
    scheme = urlparse(url).scheme
    internalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc == '':
            internalLinks.add(f'{scheme}://{netloc}/{link.attrs["href"].strip("/")}')
        elif parsed.netloc == netloc:
            internalLinks.add(link.attrs['href'])
    return list(internalLinks)

#Retrieves a list of all external links found on a page
def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc != '' and parsed.netloc != netloc:
            externalLinks.add(link.attrs['href'])
    return list(externalLinks)

def getRandomExternalLink(startingPage):
    bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
    externalLinks = getExternalLinks(bs, startingPage)
    if not len(externalLinks):
        print('No external links, looking around the site for one')
        internalLinks = getInternalLinks(bs, startingPage)
        return getRandomExternalLink(random.choice(internalLinks))
    else:
        return random.choice(externalLinks)

def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print(f'Random external link is: {externalLink}')
    followExternalOnly(externalLink)


followExternalOnly('https://www.oreilly.com/')
# Out:
# Random external link is: https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a907ad884992> in <cell line: 51>()
#      49
#      50
# ---> 51 followExternalOnly('https://www.oreilly.com/')
#
# <ipython-input-7-a907ad884992> in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# <ipython-input-7-a907ad884992> in followExternalOnly(startingSite)
#      44
#      45 def followExternalOnly(startingSite):
# ---> 46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
#      48     followExternalOnly(externalLink)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
# ...
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      39         print('No external links, looking around the site for one')
#      40         internalLinks = getInternalLinks(bs, startingPage)
# ---> 41         return getRandomExternalLink(random.choice(internalLinks))
#      42     else:
#      43         return random.choice(externalLinks)
#
# <ipython-input-7-a907ad884992> in getRandomExternalLink(startingPage)
#      34
#      35 def getRandomExternalLink(startingPage):
# ---> 36     bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
#      37     externalLinks = getExternalLinks(bs, startingPage)
#      38     if not len(externalLinks):
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     517
#     518         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519         response = self._open(req, data)
#     520
#     521         # post-process response
#
# /usr/lib/python3.10/urllib/request.py in _open(self, req, data)
#     534
#     535         protocol = req.type
# --> 536         result = self._call_chain(self.handle_open, protocol, protocol +
#     537                                   '_open', req)
#     538         if result:
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in https_open(self, req)
#    1389
#    1390         def https_open(self, req):
# -> 1391             return self.do_open(http.client.HTTPSConnection, req,
#    1392                 context=self._context, check_hostname=self._check_hostname)
#    1393
#
# /usr/lib/python3.10/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1350             except OSError as err: # timeout error
#    1351                 raise URLError(err)
# -> 1352             r = h.getresponse()
#    1353         except:
#    1354             h.close()
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = []
allIntLinks = []


def getAllExternalLinks(url):
    bs = BeautifulSoup(urlopen(url), 'html.parser')
    internalLinks = getInternalLinks(bs, url)
    externalLinks = getExternalLinks(bs, url)
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.append(link)
            print(link)

    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.append(link)
            getAllExternalLinks(link)


allIntLinks.append('https://oreilly.com')
getAllExternalLinks('https://www.oreilly.com/')
# Out:
# https://learning.oreilly.com/start-trial/
# https://oreillylearning.in/
# https://play.google.com/store/apps/details?id=com.safariflow.queue
# https://learning.oreilly.com/search/?query=author%3A%22Arianne%20Dee%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=suggestion&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Ken%20Kousen%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Neal%20Ford%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.linkedin.com/company/oreilly-media
# https://oreilly.id/
# https://oreilly.hk/
# https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# https://learning.oreilly.com/search/?query=author%3A%22Bruno%20Gon%C3%A7alves%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Kelsey%20Hightower%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.oreilly.co.jp/index.shtml
# https://itunes.apple.com/us/app/safari-to-go/id881697395
# https://learning.oreilly.com/search/?query=author%3A%22Sari%20Greene%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.youtube.com/user/OreillyMedia
# http://app.impact.com/campaign-campaign-info-v2/OReilly-Media.brand?io=6bp%2BPxNSmrilKUD6Zl0Qf20CKvd5aOUgcwBKHJBSerP5czqsKCTzqK7BCfuwlxkV
# http://app.impact.com/campaign-campaign-info-v2/OReilly-Media.brand?io=OmoCphGoM4EVcIMqQNQafRp5D9KGNfjemsGmxD%2FEGp%2BwmRMHtLf4KI6ZWNsuSDhl
# http://www.oreilly.com.cn/
# http://www.oreilly.co.jp
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-8-93fd470674d1> in <cell line: 22>()
#      20
#      21 allIntLinks.append('https://oreilly.com')
# ---> 22 getAllExternalLinks('https://www.oreilly.com/')
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#       5
#       6 def getAllExternalLinks(url):
# ----> 7     bs = BeautifulSoup(urlopen(url), 'html.parser')
#       8     internalLinks = getInternalLinks(bs, url)
#       9     externalLinks = getExternalLinks(bs, url)
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found
